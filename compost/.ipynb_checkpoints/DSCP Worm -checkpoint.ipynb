# %% [markdown]
# <table class="table table-bordered">
#     <tr>
#         <th style="width:250px"><img src='https://www.np.edu.sg/PublishingImages/Pages/default/odp/ICT.jpg' style="width: 100%; height: 125px; "></th>
#         <th style="text-align:center;"><h1>Data Science Capstone</h1><h2>Assignment 1 </h2><h3>Diploma in Data Science</h3></th>
#     </tr>
# </table>

# %%
# import the required packages

import pandas as pd
import numpy as np

# Visual
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns

from datetime import datetime
import nltk
from collections import Counter
from sklearn.preprocessing import StandardScaler, PolynomialFeatures, MinMaxScaler
from sklearn.model_selection import GridSearchCV
from xgboost import XGBRegressor

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn import tree
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
from sklearn.svm import SVR
sns.set(style="white")
# Out:
# C:\Users\fionn\anaconda3\lib\site-packages\numpy\_distributor_init.py:30: UserWarning: loaded more than 1 DLL from .libs:
# C:\Users\fionn\anaconda3\lib\site-packages\numpy\.libs\libopenblas.GK7GX5KEQ4F6UYO3P26ULGBQYHGQO7J4.gfortran-win_amd64.dll
# C:\Users\fionn\anaconda3\lib\site-packages\numpy\.libs\libopenblas.XWYDX2IKJW2NMTWSFYNGFUWKQU3LYTCZ.gfortran-win_amd64.dll
#   warnings.warn("loaded more than 1 DLL from .libs:"

# %%
# LAST UPDATED 6/5/24
mp1_231223 = pd.read_csv('data/MacPherson_Rack_01 -  23 December 2023.csv')
mp1_050424 = pd.read_csv('data/MacPherson_Rack_01 - 5 April 2024.csv')
mp1_060424 = pd.read_csv('data/MacPherson_Rack_01 - 6 April 2024.csv')
mp1_100424 = pd.read_csv('data/MacPherson_Rack_01 - 10 April 2024.csv')
mp1_140424 = pd.read_csv('data/MacPherson_Rack_01 - 14 April 2024.csv')
mp1_150424 = pd.read_csv('data/MacPherson_Rack_01 - 15 April 2024.csv')
mp1_160424 = pd.read_csv('data/MacPherson_Rack_01 - 16 April 2024.csv')

# %% [markdown]
# ### 1. Import files

# %% [markdown]
# ### Macpherson - 23 Dec 2023

# %%
mp1_231223.shape
# Out:
# (809, 16)

# %%
mp1_231223.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 809 entries, 0 to 808
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Timestamp                      809 non-null    object
#  1   Number of Worms (non-counted)  809 non-null    int64
#  2   Phosphorous01                  809 non-null    object
#  3   Phosphorous02                  809 non-null    object
#  4   Nitrogen01                     809 non-null    object
#  5   Nitrogen02                     809 non-null    object
#  6   Potassium01                    809 non-null    object
#  7   Potassium02                    809 non-null    object
#  8   Light Intensity                0 non-null      float64
#  9   Temp01                         632 non-null    float64
#  10  Hum01                          632 non-null    float64
#  11  Heat01                         632 non-null    float64
#  12  SoilM01                        553 non-null    float64
#  13  SoilM02                        553 non-null    float64
#  14  Grams of Compost Harvested     0 non-null      float64
#  15  Buzzer (NIL)                   0 non-null      float64
# dtypes: float64(8), int64(1), object(7)
# memory usage: 101.2+ KB

# %%
#Converting column name for appending files together later 
mp1_231223 = mp1_231223.rename(columns={'Buzzer (NIL)': 'Buzzer'})
mp1_231223
# Out:
#                  Timestamp  Number of Worms (non-counted) Phosphorous01  \
# 0    23 Dec 2023, 10:00 AM                             20           160
# 1    23 Dec 2023, 10:01 AM                             20           160
# 2    23 Dec 2023, 10:02 AM                             20           160
# 3    23 Dec 2023, 10:03 AM                             20           160
# 4    23 Dec 2023, 10:04 AM                             20           160
# ..                     ...                            ...           ...
# 804  23 Dec 2023, 11:24 PM                             20             ?
# 805  23 Dec 2023, 11:25 PM                             20             ?
# 806  23 Dec 2023, 11:26 PM                             20             ?
# 807  23 Dec 2023, 11:27 PM                             20             ?
# 808  23 Dec 2023, 11:28 PM                             20             ?
#
#     Phosphorous02 Nitrogen01 Nitrogen02 Potassium01 Potassium02  \
# 0             150        120        150         100          94
# 1             150        120        150         100          94
# 2             150        120        150         100          94
# 3             150        120        150         100          94
# 4             150        120        150         100          94
# ..            ...        ...        ...         ...         ...
# 804             ?          ?          ?           ?           ?
# 805             ?          ?          ?           ?           ?
# 806             ?          ?          ?           ?           ?
# 807             ?          ?          ?           ?           ?
# 808             ?          ?          ?           ?           ?
#
#      Light Intensity  Temp01  Hum01  Heat01  SoilM01  SoilM02  \
# 0                NaN    28.5    0.0    42.0      1.0      1.0
# 1                NaN    28.5    0.0    42.0      1.0      1.0
# 2                NaN    28.5    0.0    42.0      1.0      1.0
# 3                NaN    28.5    0.0    42.0      1.0      1.0
# 4                NaN    28.5   96.0    42.0      1.0      1.0
# ..               ...     ...    ...     ...      ...      ...
# 804              NaN     NaN    NaN     NaN      NaN      NaN
# 805              NaN     NaN    NaN     NaN      NaN      NaN
# 806              NaN     NaN    NaN     NaN      NaN      NaN
# 807              NaN     NaN    NaN     NaN      NaN      NaN
# 808              NaN     NaN    NaN     NaN      NaN      NaN
#
#      Grams of Compost Harvested  Buzzer
# 0                           NaN     NaN
# 1                           NaN     NaN
# 2                           NaN     NaN
# 3                           NaN     NaN
# 4                           NaN     NaN
# ..                          ...     ...
# 804                         NaN     NaN
# 805                         NaN     NaN
# 806                         NaN     NaN
# 807                         NaN     NaN
# 808                         NaN     NaN
#
# [809 rows x 16 columns]

# %% [markdown]
# ### Macpherson - 05 April 2024

# %%
mp1_050424.shape
# Out:
# (818, 16)

# %%
mp1_050424.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 818 entries, 0 to 817
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Timestamp                      818 non-null    object
#  1   Number of Worms (non-counted)  818 non-null    object
#  2   Phosphorous01                  818 non-null    object
#  3   Phosphorous02                  818 non-null    object
#  4   Nitrogen01                     818 non-null    object
#  5   Nitrogen02                     818 non-null    object
#  6   Potassium01                    818 non-null    object
#  7   Potassium02                    818 non-null    object
#  8   Light Intensity                0 non-null      float64
#  9   Temp01                         633 non-null    float64
#  10  Hum01                          633 non-null    float64
#  11  Heat01                         633 non-null    float64
#  12  SoilM01                        667 non-null    float64
#  13  SoilM02                        667 non-null    float64
#  14  Grams of Compost Harvested     3 non-null      object
#  15  Buzzer                         593 non-null    object
# dtypes: float64(6), object(10)
# memory usage: 102.4+ KB

# %%
mp1_050424
# Out:
#                 Timestamp Number of Worms (non-counted) Phosphorous01  \
# 0    5 Apr 2024, 10:00 AM                            14           193
# 1    5 Apr 2024, 10:01 AM                            14           189
# 2    5 Apr 2024, 10:02 AM                            14           163
# 3    5 Apr 2024, 10:03 AM                            14           196
# 4    5 Apr 2024, 10:04 AM                            14           142
# ..                    ...                           ...           ...
# 813  5 Apr 2024, 11:33 PM                             ?             ?
# 814  5 Apr 2024, 11:34 PM                             ?             ?
# 815  5 Apr 2024, 11:35 PM                             ?             ?
# 816  5 Apr 2024, 11:36 PM                             ?             ?
# 817  5 Apr 2024, 11:37 PM                             ?             ?
#
#     Phosphorous02 Nitrogen01 Nitrogen02 Potassium01 Potassium02  \
# 0             197        193        193         193         193
# 1             159        172        145         156         145
# 2             159        160        145         142         140
# 3             152        162        143         193         173
# 4             176        185        162         181         187
# ..            ...        ...        ...         ...         ...
# 813             ?          ?          ?           ?           ?
# 814             ?          ?          ?           ?           ?
# 815             ?          ?          ?           ?           ?
# 816             ?          ?          ?           ?           ?
# 817             ?          ?          ?           ?           ?
#
#      Light Intensity  Temp01  Hum01  Heat01  SoilM01  SoilM02  \
# 0                NaN    27.4   93.0    42.0      1.0      1.0
# 1                NaN    27.4   93.0    42.0      1.0      1.0
# 2                NaN    27.4   95.0    42.0      1.0      1.0
# 3                NaN    27.4   97.0    42.0      1.0      1.0
# 4                NaN    27.4   95.0    42.0      1.0      1.0
# ..               ...     ...    ...     ...      ...      ...
# 813              NaN     NaN    NaN     NaN      NaN      NaN
# 814              NaN     NaN    NaN     NaN      NaN      NaN
# 815              NaN     NaN    NaN     NaN      NaN      NaN
# 816              NaN     NaN    NaN     NaN      NaN      NaN
# 817              NaN     NaN    NaN     NaN      NaN      NaN
#
#     Grams of Compost Harvested Buzzer
# 0                          NaN    Off
# 1                          NaN    Off
# 2                          NaN    Off
# 3                          NaN    Off
# 4                          NaN    Off
# ..                         ...    ...
# 813                        NaN    NaN
# 814                        NaN    NaN
# 815                        NaN    NaN
# 816                        NaN    NaN
# 817                        NaN    NaN
#
# [818 rows x 16 columns]

# %% [markdown]
# ### Macpherson - 06 April 2024

# %%
mp1_060424.shape
# Out:
# (999, 17)

# %%
mp1_060424.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 999 entries, 0 to 998
# Data columns (total 17 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Timestamp                      840 non-null    object
#  1   Number of Worms (non-counted)  588 non-null    float64
#  2   Phosphorous01                  840 non-null    object
#  3   Phosphorous02                  840 non-null    object
#  4   Nitrogen01                     840 non-null    object
#  5   Nitrogen02                     840 non-null    object
#  6   Potassium01                    840 non-null    object
#  7   Potassium02                    840 non-null    object
#  8   Light Intensity                0 non-null      float64
#  9   Temp01                         632 non-null    float64
#  10  Hum01                          774 non-null    float64
#  11  Heat01                         632 non-null    float64
#  12  SoilM01                        502 non-null    float64
#  13  SoilM02                        502 non-null    float64
#  14  Grams of Compost Harvested     0 non-null      float64
#  15  Buzzer                         593 non-null    object
#  16  Compost Notes                  1 non-null      object
# dtypes: float64(8), object(9)
# memory usage: 132.8+ KB

# %%
#first 7 rows have '?' for NPK values
mp1_060424
# Out:
#                 Timestamp  Number of Worms (non-counted) Phosphorous01  \
# 0    6 Apr 2024, 10:00 AM                           14.0             ?
# 1    6 Apr 2024, 10:01 AM                           14.0             ?
# 2    6 Apr 2024, 10:02 AM                           14.0             ?
# 3    6 Apr 2024, 10:03 AM                           14.0             ?
# 4    6 Apr 2024, 10:04 AM                           14.0             ?
# ..                    ...                            ...           ...
# 994                   NaN                            NaN           NaN
# 995                   NaN                            NaN           NaN
# 996                   NaN                            NaN           NaN
# 997                   NaN                            NaN           NaN
# 998                   NaN                            NaN           NaN
#
#     Phosphorous02 Nitrogen01 Nitrogen02 Potassium01 Potassium02  \
# 0               ?          ?          ?           ?           ?
# 1               ?          ?          ?           ?           ?
# 2               ?          ?          ?           ?           ?
# 3               ?          ?          ?           ?           ?
# 4               ?          ?          ?           ?           ?
# ..            ...        ...        ...         ...         ...
# 994           NaN        NaN        NaN         NaN         NaN
# 995           NaN        NaN        NaN         NaN         NaN
# 996           NaN        NaN        NaN         NaN         NaN
# 997           NaN        NaN        NaN         NaN         NaN
# 998           NaN        NaN        NaN         NaN         NaN
#
#      Light Intensity  Temp01  Hum01  Heat01  SoilM01  SoilM02  \
# 0                NaN    27.4   94.0    42.0      1.0      1.0
# 1                NaN    27.4   97.0    42.0      1.0      1.0
# 2                NaN    27.4   98.0    42.0      1.0      1.0
# 3                NaN    27.4   96.0    42.0      1.0      1.0
# 4                NaN    27.4   93.0    42.0      1.0      1.0
# ..               ...     ...    ...     ...      ...      ...
# 994              NaN     NaN    0.0     NaN      NaN      NaN
# 995              NaN     NaN    0.0     NaN      NaN      NaN
# 996              NaN     NaN    0.0     NaN      NaN      NaN
# 997              NaN     NaN    0.0     NaN      NaN      NaN
# 998              NaN     NaN    0.0     NaN      NaN      NaN
#
#      Grams of Compost Harvested Buzzer Compost Notes
# 0                           NaN    Off           NaN
# 1                           NaN    Off           NaN
# 2                           NaN    Off           NaN
# 3                           NaN    Off           NaN
# 4                           NaN    Off           NaN
# ..                          ...    ...           ...
# 994                         NaN    NaN           NaN
# 995                         NaN    NaN           NaN
# 996                         NaN    NaN           NaN
# 997                         NaN    NaN           NaN
# 998                         NaN    NaN           NaN
#
# [999 rows x 17 columns]

# %% [markdown]
# ### Macpherson - 10 April 2024

# %%
mp1_100424.shape
# Out:
# (377, 16)

# %%
mp1_100424.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 377 entries, 0 to 376
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Timestamp                      377 non-null    object
#  1   Number of Worms (non-counted)  377 non-null    int64
#  2   Phosphorous01                  377 non-null    int64
#  3   Phosphorous02                  377 non-null    int64
#  4   Nitrogen01                     377 non-null    int64
#  5   Nitrogen02                     377 non-null    int64
#  6   Potassium01                    377 non-null    int64
#  7   Potassium02                    377 non-null    int64
#  8   Light Intensity                0 non-null      float64
#  9   Temp01                         377 non-null    float64
#  10  Hum01                          377 non-null    int64
#  11  Heat01                         377 non-null    int64
#  12  SoilM01                        291 non-null    float64
#  13  SoilM02                        291 non-null    float64
#  14  Grams of Compost Harvested     0 non-null      float64
#  15  Buzzer                         377 non-null    object
# dtypes: float64(5), int64(9), object(2)
# memory usage: 47.2+ KB

# %%
mp1_100424
# Out:
#                  Timestamp  Number of Worms (non-counted)  Phosphorous01  \
# 0    10 Apr 2024, 10:00 AM                             14            135
# 1    10 Apr 2024, 10:01 AM                             14            133
# 2    10 Apr 2024, 10:02 AM                             14            133
# 3    10 Apr 2024, 10:03 AM                             14            178
# 4    10 Apr 2024, 10:04 AM                             14            149
# ..                     ...                            ...            ...
# 372   10 Apr 2024, 4:12 PM                             14            160
# 373   10 Apr 2024, 4:13 PM                             14            161
# 374   10 Apr 2024, 4:14 PM                             14            160
# 375   10 Apr 2024, 4:15 PM                             14            160
# 376   10 Apr 2024, 4:16 PM                             14            159
#
#      Phosphorous02  Nitrogen01  Nitrogen02  Potassium01  Potassium02  \
# 0              146         193         193          193          193
# 1              131         172         145          156          145
# 2              149         160         145          142          140
# 3              185         162         143          193          173
# 4              135         185         162          181          187
# ..             ...         ...         ...          ...          ...
# 372            182         163         141          193          173
# 373            182         163         145          182          180
# 374            182         163         162          171          170
# 375            182         161         165          201          173
# 376            182         162         177          153          181
#
#      Light Intensity  Temp01  Hum01  Heat01  SoilM01  SoilM02  \
# 0                NaN    27.4     99      42      1.0      1.0
# 1                NaN    27.4     93      42      1.0      1.0
# 2                NaN    27.4     97      42      1.0      1.0
# 3                NaN    27.4     98      42      1.0      1.0
# 4                NaN    27.4     95      42      1.0      1.0
# ..               ...     ...    ...     ...      ...      ...
# 372              NaN    31.9     96      43      NaN      NaN
# 373              NaN    31.9     96      43      NaN      NaN
# 374              NaN    31.9     96      43      NaN      NaN
# 375              NaN    31.9     96      43      NaN      NaN
# 376              NaN    31.9     98      43      NaN      NaN
#
#      Grams of Compost Harvested Buzzer
# 0                           NaN    Off
# 1                           NaN    Off
# 2                           NaN    Off
# 3                           NaN    Off
# 4                           NaN    Off
# ..                          ...    ...
# 372                         NaN    Off
# 373                         NaN    Off
# 374                         NaN    Off
# 375                         NaN    Off
# 376                         NaN    Off
#
# [377 rows x 16 columns]

# %% [markdown]
# ### Macpherson - 14 April 2024

# %%
mp1_140424.shape
# Out:
# (525, 16)

# %%
mp1_140424.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 525 entries, 0 to 524
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Timestamp                      525 non-null    object
#  1   Number of Worms (non-counted)  1 non-null      object
#  2   Phosphorous01                  311 non-null    object
#  3   Phosphorous02                  311 non-null    object
#  4   Nitrogen01                     311 non-null    object
#  5   Nitrogen02                     311 non-null    object
#  6   Potassium01                    311 non-null    object
#  7   Potassium02                    311 non-null    object
#  8   Light Intensity                1 non-null      object
#  9   Temp01                         525 non-null    object
#  10  Hum01                          525 non-null    object
#  11  Heat01                         525 non-null    object
#  12  SoilM01                        360 non-null    object
#  13  SoilM02                        360 non-null    object
#  14  Grams of Compost Harvested     1 non-null      object
#  15  Buzzer                         525 non-null    object
# dtypes: object(16)
# memory usage: 65.8+ KB

# %%
mp1_140424
# Out:
#                  Timestamp Number of Worms (non-counted) Phosphorous01  \
# 0                     Unit                        Number           ppm
# 1    14 Apr 2024, 10:00 AM                           NaN           146
# 2    14 Apr 2024, 10:01 AM                           NaN           146
# 3    14 Apr 2024, 10:02 AM                           NaN           146
# 4    14 Apr 2024, 10:03 AM                           NaN           146
# ..                     ...                           ...           ...
# 520   14 Apr 2024, 6:39 PM                           NaN           NaN
# 521   14 Apr 2024, 6:40 PM                           NaN           NaN
# 522   14 Apr 2024, 6:41 PM                           NaN           NaN
# 523   14 Apr 2024, 6:42 PM                           NaN           NaN
# 524   14 Apr 2024, 6:43 PM                           NaN           NaN
#
#     Phosphorous02 Nitrogen01 Nitrogen02 Potassium01 Potassium02  \
# 0             ppm        ppm        ppm         ppm         ppm
# 1             169        131        156         169         160
# 2             149        131        159         183         184
# 3             147        131        159         136         175
# 4             130        132        157         145         165
# ..            ...        ...        ...         ...         ...
# 520           NaN        NaN        NaN         NaN         NaN
# 521           NaN        NaN        NaN         NaN         NaN
# 522           NaN        NaN        NaN         NaN         NaN
# 523           NaN        NaN        NaN         NaN         NaN
# 524           NaN        NaN        NaN         NaN         NaN
#
#     Light Intensity Temp01 Hum01 Heat01 SoilM01 SoilM02  \
# 0               lux  DEG C     %    NIL     NIL     NIL
# 1               NaN   28.5     0     42       1       1
# 2               NaN   27.4     0     42       1       1
# 3               NaN   27.4     0     42       1       1
# 4               NaN   27.4     0     42       1       1
# ..              ...    ...   ...    ...     ...     ...
# 520             NaN   32.8    93     43       1       1
# 521             NaN   32.8    94     43       1       1
# 522             NaN   32.8    94     43       1       1
# 523             NaN   32.8    94     43       1       1
# 524             NaN   33.4    94     43       1       1
#
#     Grams of Compost Harvested Buzzer
# 0                            g    NIL
# 1                          NaN    Off
# 2                          NaN    Off
# 3                          NaN    Off
# 4                          NaN    Off
# ..                         ...    ...
# 520                        NaN    Off
# 521                        NaN    Off
# 522                        NaN    Off
# 523                        NaN    Off
# 524                        NaN    Off
#
# [525 rows x 16 columns]

# %%
#Dropping the first column 
mp1_140424.drop(0, inplace=True) # Row of units and measurements
mp1_140424.reset_index(drop=True, inplace=True)
mp1_140424
# Out:
#                  Timestamp Number of Worms (non-counted) Phosphorous01  \
# 0    14 Apr 2024, 10:00 AM                           NaN           146
# 1    14 Apr 2024, 10:01 AM                           NaN           146
# 2    14 Apr 2024, 10:02 AM                           NaN           146
# 3    14 Apr 2024, 10:03 AM                           NaN           146
# 4    14 Apr 2024, 10:04 AM                           NaN           146
# ..                     ...                           ...           ...
# 519   14 Apr 2024, 6:39 PM                           NaN           NaN
# 520   14 Apr 2024, 6:40 PM                           NaN           NaN
# 521   14 Apr 2024, 6:41 PM                           NaN           NaN
# 522   14 Apr 2024, 6:42 PM                           NaN           NaN
# 523   14 Apr 2024, 6:43 PM                           NaN           NaN
#
#     Phosphorous02 Nitrogen01 Nitrogen02 Potassium01 Potassium02  \
# 0             169        131        156         169         160
# 1             149        131        159         183         184
# 2             147        131        159         136         175
# 3             130        132        157         145         165
# 4             153        132        157         133         138
# ..            ...        ...        ...         ...         ...
# 519           NaN        NaN        NaN         NaN         NaN
# 520           NaN        NaN        NaN         NaN         NaN
# 521           NaN        NaN        NaN         NaN         NaN
# 522           NaN        NaN        NaN         NaN         NaN
# 523           NaN        NaN        NaN         NaN         NaN
#
#     Light Intensity Temp01 Hum01 Heat01 SoilM01 SoilM02  \
# 0               NaN   28.5     0     42       1       1
# 1               NaN   27.4     0     42       1       1
# 2               NaN   27.4     0     42       1       1
# 3               NaN   27.4     0     42       1       1
# 4               NaN   29.1     0     42       1       1
# ..              ...    ...   ...    ...     ...     ...
# 519             NaN   32.8    93     43       1       1
# 520             NaN   32.8    94     43       1       1
# 521             NaN   32.8    94     43       1       1
# 522             NaN   32.8    94     43       1       1
# 523             NaN   33.4    94     43       1       1
#
#     Grams of Compost Harvested Buzzer
# 0                          NaN    Off
# 1                          NaN    Off
# 2                          NaN    Off
# 3                          NaN    Off
# 4                          NaN    Off
# ..                         ...    ...
# 519                        NaN    Off
# 520                        NaN    Off
# 521                        NaN    Off
# 522                        NaN    Off
# 523                        NaN    Off
#
# [524 rows x 16 columns]

# %% [markdown]
# ### Macpherson - 15 April 2024

# %%
mp1_150424.shape
# Out:
# (56, 17)

# %%
mp1_150424.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 56 entries, 0 to 55
# Data columns (total 17 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Timestamp                      56 non-null     object
#  1   Number of Worms (non-counted)  56 non-null     object
#  2   Phosphorous01                  56 non-null     object
#  3   Phosphorous02                  56 non-null     object
#  4   Nitrogen01                     56 non-null     object
#  5   Nitrogen02                     56 non-null     object
#  6   Potassium01                    56 non-null     object
#  7   Potassium02                    56 non-null     object
#  8   Light Intensity                56 non-null     object
#  9   Temp01                         56 non-null     object
#  10  Hum01                          56 non-null     object
#  11  Heat01                         56 non-null     object
#  12  SoilM01                        56 non-null     object
#  13  SoilM02                        56 non-null     object
#  14  pH Rod 1                       56 non-null     object
#  15  pH Rod 2                       56 non-null     object
#  16  Grams of Compost Harvested     2 non-null      object
# dtypes: object(17)
# memory usage: 7.6+ KB

# %%
mp1_150424.drop(0, inplace=True) # Row of units and measurements
mp1_150424.reset_index(drop=True, inplace=True)
mp1_150424
# Out:
#                 Timestamp Number of Worms (non-counted) Phosphorous01  \
# 0   15 Apr 2024, 10:00 AM                            30            54
# 1   15 Apr 2024, 10:10 AM                            30            54
# 2   15 Apr 2024, 10:20 AM                            30            54
# 3   15 Apr 2024, 10:30 AM                            30            54
# 4   15 Apr 2024, 10:40 AM                            30            54
# 5   15 Apr 2024, 10:50 AM                            30            54
# 6   15 Apr 2024, 11:00 AM                            30             0
# 7   15 Apr 2024, 11:10 AM                            30             0
# 8   15 Apr 2024, 11:20 AM                            30             0
# 9   15 Apr 2024, 11:30 AM                            30             0
# 10  15 Apr 2024, 11:40 AM                            30             0
# 11  15 Apr 2024, 11:50 AM                            30             0
# 12  15 Apr 2024, 12:00 PM                            30            56
# 13  15 Apr 2024, 12:10 PM                            30            58
# 14  15 Apr 2024, 12:20 PM                            30            58
# 15  15 Apr 2024, 12:30 PM                            30            58
# 16  15 Apr 2024, 12:40 PM                            30            58
# 17  15 Apr 2024, 12:50 PM                            30            58
# 18   15 Apr 2024, 1:00 PM                            30            58
# 19   15 Apr 2024, 1:10 PM                            30            58
# 20   15 Apr 2024, 1:20 PM                            30            58
# 21   15 Apr 2024, 1:30 PM                            30            58
# 22   15 Apr 2024, 1:40 PM                            30            58
# 23   15 Apr 2024, 1:50 PM                            30            58
# 24   15 Apr 2024, 2:00 PM                            30            58
# 25   15 Apr 2024, 2:10 PM                            30            58
# 26   15 Apr 2024, 2:20 PM                            30            56
# 27   15 Apr 2024, 2:30 PM                            30            56
# 28   15 Apr 2024, 2:40 PM                            30            56
# 29   15 Apr 2024, 2:50 PM                            30            56
# 30   15 Apr 2024, 3:00 PM                            30            56
# 31   15 Apr 2024, 3:10 PM                            30            56
# 32   15 Apr 2024, 3:20 PM                            30            56
# 33   15 Apr 2024, 3:30 PM                            30            56
# 34   15 Apr 2024, 3:40 PM                            30            56
# 35   15 Apr 2024, 3:50 PM                            30            56
# 36   15 Apr 2024, 4:00 PM                            30            56
# 37   15 Apr 2024, 4:10 PM                            30            56
# 38   15 Apr 2024, 4:20 PM                            30            56
# 39   15 Apr 2024, 4:30 PM                            30            56
# 40   15 Apr 2024, 4:40 PM                            30            56
# 41   15 Apr 2024, 4:50 PM                            30            56
# 42   15 Apr 2024, 5:00 PM                            30            56
# 43   15 Apr 2024, 5:10 PM                            30            56
# 44   15 Apr 2024, 5:20 PM                            30            56
# 45   15 Apr 2024, 5:30 PM                            30            56
# 46   15 Apr 2024, 5:40 PM                            30            56
# 47   15 Apr 2024, 5:50 PM                            30            56
# 48   15 Apr 2024, 6:00 PM                            30            56
# 49   15 Apr 2024, 6:10 PM                            30            56
# 50   15 Apr 2024, 6:20 PM                            30            56
# 51   15 Apr 2024, 6:30 PM                            30            56
# 52   15 Apr 2024, 6:40 PM                            30            56
# 53   15 Apr 2024, 6:50 PM                            30            56
# 54   15 Apr 2024, 7:00 PM                            30            56
#
#    Phosphorous02 Nitrogen01 Nitrogen02 Potassium01 Potassium02  \
# 0             56        142        142         132         122
# 1             56        142        142         110         120
# 2             56        140        140         132         123
# 3             56        140        140         129         123
# 4             56        140        140         131         123
# 5             56        140        140         131         123
# 6              0          0          0           0           0
# 7              0          0          0           0           0
# 8              0          0          0           0           0
# 9              0          0          0           0           0
# 10             0          0          0           0           0
# 11             0          0          0           0           0
# 12            59         83         51          72          71
# 13            59         83         51          72          71
# 14            59         82         51          72          71
# 15            59         83         51          72          71
# 16            59         83         51          72          71
# 17            59         83         51          72          71
# 18            59         81         51          72          71
# 19            59         83         51          72          71
# 20            59         82         51          72          70
# 21            59         83         51          72          71
# 22            59         83         51          70          72
# 23            59         82         51          72          72
# 24            59         83         51          72          72
# 25            59         83         51          72          72
# 26            59         83         51          72          72
# 27            59         83         51          72          72
# 28            59         83         51          72          72
# 29            59         83         51          72          72
# 30            59         83         51          72          72
# 31            57         81         51          72          72
# 32            56         83         51          72          72
# 33            56         81         51          72          70
# 34            57         81         51          72          72
# 35            56         81         51          72          70
# 36            59         81         51          70          72
# 37            59         83         51          70          72
# 38            59         82         51          70          72
# 39            59         83         51          69          69
# 40            59         81         51          72          70
# 41            59         81         51          72          69
# 42            59         81         51          72          72
# 43            59         83         51          72          72
# 44            59         81         51          72          72
# 45            59         81         51          72          72
# 46            56         81         51          71          72
# 47            59         81         51          72          72
# 48            56         81         51          72          72
# 49            56         81         51          70          72
# 50            59         83         51          71          70
# 51            59         82         51          72          72
# 52            59         83         51          72          72
# 53            59         81         51          72          72
# 54            59         81         51          72          72
#
#    Light Intensity Temp01 Hum01 Heat01 SoilM01 SoilM02 pH Rod 1 pH Rod 2  \
# 0               29   32.7    80     95       1       1   121.85  -126.85
# 1               29   32.7    81     95       1       1   117.67  -124.67
# 2               29   32.7    81     93       1       1   117.29  -118.29
# 3               29   32.7    80     90       1       1   115.58  -116.58
# 4               29   32.7    79     95       1       1   120.51  -127.51
# 5               29   32.7    78     94       1       1   121.42  -127.42
# 6               29   33.8    79     93       1       1   116.24  -117.24
# 7               29   35.3    77     90       1       1   196.41  -200.41
# 8               29   35.0    76     90       1       1   197.43  -202.43
# 9               29   34.9    78     93       1       1   196.71  -199.71
# 10              33   34.8    78     89       1       1   203.45  -208.45
# 11              35   35.1    79     92       1       1   200.73  -207.73
# 12              70   34.8    80     90       1       1   197.74  -203.74
# 13              71   33.3    81     96       1       1   202.10  -207.10
# 14              72   33.2    81     97       1       1   197.02  -198.02
# 15              37   33.0    82     97       1       1   201.90  -208.90
# 16              35   33.0    83     95       1       1   198.89  -203.89
# 17              37   33.5    83     95       1       1   204.11  -206.11
# 18              37   33.5    83     95       1       1   199.50  -204.50
# 19              34   33.5    82     91       1       1   200.25  -206.25
# 20              34   33.5    83     92       1       1   201.77  -202.77
# 21               2   33.5    84     93       1       1   204.10  -211.10
# 22              35   33.5    84     94       1       1   193.28  -194.28
# 23              35   33.5    84     92       1       1   188.01  -190.01
# 24              34   33.5    93     95       1       1   185.42  -192.42
# 25              34   34.6    83     93       1       1   186.44  -193.44
# 26              35   35.3    83     93       1       1   189.30  -192.30
# 27              36   33.5    79     95       1       1   193.60  -196.60
# 28              36   33.5    79     95       1       1   186.94  -189.94
# 29              36   28.5    79     92       1       1   186.33  -192.33
# 30              35   28.5    79     90       1       1   187.95  -193.95
# 31              34   28.5    77     92       1       1   186.24  -189.24
# 32              34   28.5    78     93       1       1   185.55  -191.55
# 33              33   28.5    78     90       1       1   186.69  -189.69
# 34               2   28.5    78     92       1       1   187.39  -189.39
# 35              35   28.5    77     92       1       1   188.82  -192.82
# 36              34   28.5    77     90       1       1   190.01  -197.01
# 37              33   28.5    77     93       1       1   185.90  -187.90
# 38              33   28.5    76     94       1       1   187.92  -192.92
# 39              34   28.5    77     95       1       1   189.10  -193.10
# 40              33   28.5    75     95       1       1   185.92  -186.92
# 41              33   28.5    75     95       1       1   185.45  -187.45
# 42              33   28.5    75     95       1       1   194.74  -198.74
# 43              32   28.5    75     95       1       1   187.55  -190.55
# 44              32   28.5    75     95       1       1   185.81  -186.81
# 45              28   28.5    75     95       1       1   186.89  -188.89
# 46              28   28.5    76     95       1       1   186.93  -189.93
# 47              27   28.5    76     95       1       1   187.82  -194.82
# 48              27   28.5    74     95       1       1   190.23  -193.23
# 49              29   28.5    75     95       1       1   186.05  -191.05
# 50              29   28.5    76     95       1       1   191.74  -198.74
# 51              28   28.5    76     95       1       1   187.67  -193.67
# 52              28   28.5    76     95       1       1   190.17  -191.17
# 53              27   28.5    74     95       1       1   185.81  -190.81
# 54              30   28.5    74     95       1       1   192.52  -197.52
#
#    Grams of Compost Harvested
# 0                         NaN
# 1                         NaN
# 2                         NaN
# 3                         NaN
# 4                         NaN
# 5                         NaN
# 6                         NaN
# 7          60g harvested here
# 8                         NaN
# 9                         NaN
# 10                        NaN
# 11                        NaN
# 12                        NaN
# 13                        NaN
# 14                        NaN
# 15                        NaN
# 16                        NaN
# 17                        NaN
# 18                        NaN
# 19                        NaN
# 20                        NaN
# 21                        NaN
# 22                        NaN
# 23                        NaN
# 24                        NaN
# 25                        NaN
# 26                        NaN
# 27                        NaN
# 28                        NaN
# 29                        NaN
# 30                        NaN
# 31                        NaN
# 32                        NaN
# 33                        NaN
# 34                        NaN
# 35                        NaN
# 36                        NaN
# 37                        NaN
# 38                        NaN
# 39                        NaN
# 40                        NaN
# 41                        NaN
# 42                        NaN
# 43                        NaN
# 44                        NaN
# 45                        NaN
# 46                        NaN
# 47                        NaN
# 48                        NaN
# 49                        NaN
# 50                        NaN
# 51                        NaN
# 52                        NaN
# 53                        NaN
# 54                        NaN

# %% [markdown]
# ### Macpherson - 16 April 2024

# %%
mp1_160424.shape
# Out:
# (55, 18)

# %%
mp1_160424.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55 entries, 0 to 54
# Data columns (total 18 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Timestamp                      55 non-null     object
#  1   Number of Worms (non-counted)  55 non-null     object
#  2   Phosphorous01                  55 non-null     object
#  3   Phosphorous02                  55 non-null     object
#  4   Nitrogen01                     55 non-null     object
#  5   Nitrogen02                     55 non-null     object
#  6   Potassium01                    55 non-null     object
#  7   Potassium02                    55 non-null     object
#  8   Light Intensity                55 non-null     object
#  9   Temp01                         55 non-null     object
#  10  Hum01                          55 non-null     object
#  11  Heat01                         55 non-null     object
#  12  SoilM01                        55 non-null     object
#  13  SoilM02                        55 non-null     object
#  14  Buzzer                         55 non-null     object
#  15  pH Rod 1                       55 non-null     object
#  16  pH Rod 2                       55 non-null     object
#  17  Grams of Compost Harvested     1 non-null      object
# dtypes: object(18)
# memory usage: 7.9+ KB

# %%
mp1_160424.drop(0, inplace=True) # Row of units and measurements
mp1_160424.reset_index(drop=True, inplace=True)
mp1_160424
# Out:
#                 Timestamp Number of Worms (non-counted) Phosphorous01  \
# 0   16 Apr 2024, 10:00 AM                 28 (2 escape)            56
# 1   16 Apr 2024, 10:10 AM                            28            56
# 2   16 Apr 2024, 10:20 AM                            28            56
# 3   16 Apr 2024, 10:30 AM                            28            56
# 4   16 Apr 2024, 10:40 AM                            28            56
# 5   16 Apr 2024, 10:50 AM                            28            56
# 6   16 Apr 2024, 11:00 AM                            28            56
# 7   16 Apr 2024, 11:10 AM                            28            58
# 8   16 Apr 2024, 11:20 AM                            28            58
# 9   16 Apr 2024, 11:30 AM                            28            58
# 10  16 Apr 2024, 11:40 AM                            28            58
# 11  16 Apr 2024, 11:50 AM                            28            58
# 12  16 Apr 2024, 12:00 PM                            28            58
# 13  16 Apr 2024, 12:10 PM                            28            58
# 14  16 Apr 2024, 12:20 PM                            28            58
# 15  16 Apr 2024, 12:30 PM                            28            58
# 16  16 Apr 2024, 12:40 PM                            28            58
# 17  16 Apr 2024, 12:50 PM                            28            58
# 18   16 Apr 2024, 1:00 PM                            28            58
# 19   16 Apr 2024, 1:10 PM                            28            58
# 20   16 Apr 2024, 1:20 PM                            28            58
# 21   16 Apr 2024, 1:30 PM                            28            58
# 22   16 Apr 2024, 1:40 PM                            28            58
# 23   16 Apr 2024, 1:50 PM                            28            58
# 24   16 Apr 2024, 2:00 PM                            28            58
# 25   16 Apr 2024, 2:10 PM                            28            58
# 26   16 Apr 2024, 2:20 PM                            28            58
# 27   16 Apr 2024, 2:30 PM                            28            58
# 28   16 Apr 2024, 2:40 PM                            28            58
# 29   16 Apr 2024, 2:50 PM                            28            58
# 30   16 Apr 2024, 3:00 PM                            28            58
# 31   16 Apr 2024, 3:10 PM                            28            60
# 32   16 Apr 2024, 3:20 PM                            28            60
# 33   16 Apr 2024, 3:30 PM                            28            60
# 34   16 Apr 2024, 3:40 PM                            28            58
# 35   16 Apr 2024, 3:50 PM                            28            59
# 36   16 Apr 2024, 4:00 PM                            28            58
# 37   16 Apr 2024, 4:10 PM                            28            58
# 38   16 Apr 2024, 4:20 PM                            28            58
# 39   16 Apr 2024, 4:30 PM                            28            58
# 40   16 Apr 2024, 4:40 PM                            28            60
# 41   16 Apr 2024, 4:50 PM                            28            56
# 42   16 Apr 2024, 5:00 PM                            28            56
# 43   16 Apr 2024, 5:10 PM                            28            56
# 44   16 Apr 2024, 5:20 PM                            28            56
# 45   16 Apr 2024, 5:30 PM                            28            56
# 46   16 Apr 2024, 5:40 PM                            28            56
# 47   16 Apr 2024, 5:50 PM                            28            56
# 48   16 Apr 2024, 6:00 PM                            28            56
# 49   16 Apr 2024, 6:10 PM                            28            60
# 50   16 Apr 2024, 6:20 PM                            28            56
# 51   16 Apr 2024, 6:30 PM                            28            56
# 52   16 Apr 2024, 6:40 PM                            28            59
# 53   16 Apr 2024, 6:50 PM                            28            59
#
#    Phosphorous02 Nitrogen01 Nitrogen02 Potassium01 Potassium02  \
# 0             59         81         51          72          72
# 1             59         81         51          72          74
# 2             59         81         51          72          72
# 3             59         81         51          72          72
# 4             59         81         51          72          73
# 5             59         81         51          72          72
# 6             59         81         51          72          72
# 7             63         83         53          72          73
# 8             63         83         53          72          73
# 9             63         83         53          72          73
# 10            63         83         53          72          74
# 11            63         83         53          72          74
# 12            63         83         53          72          75
# 13            63         83         53          72          75
# 14            63         83         53          72          75
# 15            63         83         53          72          75
# 16            64         83         53          72          75
# 17            63         83         53          72          75
# 18            65         83         53          72          75
# 19            62         83         53          72          75
# 20            63         83         53          72          73
# 21            63         83         53          72          76
# 22            63         83         53          72          76
# 23            63         83         53          72          76
# 24            63         83         53          72          76
# 25            63         83         53          72          76
# 26            63         83         53          72          76
# 27            64         83         53          72          76
# 28            63         83         53          72          76
# 29            63         83         53          72          76
# 30            63         83         53          72          76
# 31            63         83         53          72          78
# 32            62         83         53          72          78
# 33            63         83         53          72          78
# 34            63         83         53          72          72
# 35            62         83         53          72          77
# 36            63         83         53          72          77
# 37            63         83         53          72          77
# 38            63         83         53          72          77
# 39            63         83         53          72          77
# 40            63         83         56          72          77
# 41            63         83         56          72          77
# 42            63         83         56          72          77
# 43            63         83         56          72          76
# 44            63         83         56          72          76
# 45            63         83         54          72          76
# 46            63         83         53          72          76
# 47            63         83         56          72          76
# 48            63         83         53          72          76
# 49            63         83         53          72          76
# 50            62         83         57          72          78
# 51            63         83         57          72          78
# 52            63         83         57          72          78
# 53            63         83         57          72          78
#
#    Light Intensity Temp01 Hum01 Heat01 SoilM01 SoilM02 Buzzer pH Rod 1  \
# 0               29   28.1    90     93       1       1   0.00   189.01
# 1               29   28.1    88     92       1       1   0.00   203.22
# 2               29   28.2    83     93       1       1   0.00   198.01
# 3               29   28.2    87     91       1       1   0.00   208.12
# 4               29   28.3    84     91       1       1   0.00   204.37
# 5               29   28.3    88     92       1       1   0.00   190.00
# 6               29   28.4    86     90       1       1   0.00   187.09
# 7               29   28.4    82     93       1       1   0.00   190.38
# 8               29   28.5    84     92       1       1   0.00   180.62
# 9               29   28.5    88     93       1       1   0.00   195.09
# 10              33   28.6    86     91       1       1   0.00   186.72
# 11              35   28.6    80     92       1       1   0.00   193.22
# 12              70   28.7    78     90       1       1   0.00   186.48
# 13              71   28.7    78     90       1       1   0.00   200.99
# 14              72   28.8    83     92       1       1   0.00   209.67
# 15              37   28.9    79     91       1       1   0.00   199.21
# 16              35   28.9    82     91       1       1   0.00   208.18
# 17              37   31.0    78     93       1       1   0.00   187.72
# 18              37   31.1    79     91       1       1   0.00   196.28
# 19              34   31.2    75     90       1       1   0.00   185.23
# 20              34   31.3    72     90       1       1   0.00   202.16
# 21              36   31.3    75     90       1       1   0.00   208.65
# 22              35   31.4    77     90       1       1   0.00   209.30
# 23              35   31.5    73     92       1       1   0.00   204.13
# 24              34   31.6    76     93       1       1   0.00   208.68
# 25              34   31.7    77     91       1       1   0.00   207.53
# 26              35   31.8    74     90       1       1   0.00   190.72
# 27              36   31.9    70     90       1       1   0.00   183.08
# 28              36   32.0    73     93       1       1   0.00   181.02
# 29              36   32.0    71     91       1       1   0.00   206.05
# 30              35   29.8    75     90       1       1   0.00   194.84
# 31              34   31.9    74     91       1       1   0.00   183.47
# 32              34   31.7    71     90       1       1   0.00   189.42
# 33              33   31.7    73     93       1       1   0.00   201.35
# 34               2   31.7    75     92       1       1   0.00   200.01
# 35              35   31.7    73     92       1       1   0.00   209.52
# 36              34   30.3    80     93       1       1   0.00   188.14
# 37              33   30.3    80     90       1       1   0.00   186.34
# 38              33   30.4    80     90       1       1   0.00   180.34
# 39              34   30.5    74     90       1       1   0.00   184.92
# 40              33   30.6    79     93       1       1   0.00   200.15
# 41              33   30.6    80     91       0       0   1.00   182.52
# 42              33   30.7    76     93       0       0   1.00   208.88
# 43              32   30.8    77     91       0       0   1.00   186.35
# 44              32   30.9    73     90       0       0   1.00   185.38
# 45              28   28.7    83     92       1       1   0.00   185.56
# 46              28   28.2    81     91       1       1   0.00   204.09
# 47              27   28.2    89     93       1       1   0.00   200.87
# 48              27   28.2    89     93       1       1   0.00   196.28
# 49              29   28.2    80     90       1       1   0.00   197.40
# 50              29   29.3    78     91       1       1   0.00   184.16
# 51              28   29.1    81     91       1       1   0.00   201.29
# 52              28   28.2    86     90       1       1   0.00   197.65
# 53              27   28.2    84     91       1       1   0.00   185.93
#
#    pH Rod 2 Grams of Compost Harvested
# 0    200.12                        NaN
# 1    200.84                        NaN
# 2    200.73                        NaN
# 3    200.92                        NaN
# 4    200.34                        NaN
# 5    200.49                        NaN
# 6    200.64                        NaN
# 7    200.79                        NaN
# 8    200.63                        NaN
# 9    200.78                        NaN
# 10   200.49                        NaN
# 11   200.87                        NaN
# 12   200.11                        NaN
# 13   200.87                        NaN
# 14   200.59                        NaN
# 15   200.88                        NaN
# 16   200.18                        NaN
# 17   200.73                        NaN
# 18   200.23                        NaN
# 19   200.42                        NaN
# 20   200.74                        NaN
# 21   200.13                        NaN
# 22   200.44                        NaN
# 23   200.28                        NaN
# 24   200.91                        NaN
# 25   200.73                        NaN
# 26   200.41                        NaN
# 27   200.71                        NaN
# 28   200.24                        NaN
# 29   200.24                        NaN
# 30   200.87                        NaN
# 31   200.25                        NaN
# 32   200.56                        NaN
# 33   200.69                        NaN
# 34   200.90                        NaN
# 35   200.22                        NaN
# 36   200.33                        NaN
# 37   200.04                        NaN
# 38   200.16                        NaN
# 39   200.71                        NaN
# 40   200.72                        NaN
# 41   200.86                        NaN
# 42   200.51                        NaN
# 43   200.00                        NaN
# 44   200.61                        NaN
# 45   200.72                        NaN
# 46   200.91                        NaN
# 47   200.27                        NaN
# 48   200.18                        NaN
# 49   200.10                        NaN
# 50   200.96                        NaN
# 51   200.60                        NaN
# 52   200.57                        NaN
# 53   200.38                        NaN

# %% [markdown]
# ### 2. Exploration

# %%
#appending files together
df = pd.concat([mp1_231223, mp1_050424, mp1_060424, mp1_100424, mp1_140424, mp1_150424, mp1_160424], axis=0)
df
# Out:
#                 Timestamp Number of Worms (non-counted) Phosphorous01  \
# 0   23 Dec 2023, 10:00 AM                            20           160
# 1   23 Dec 2023, 10:01 AM                            20           160
# 2   23 Dec 2023, 10:02 AM                            20           160
# 3   23 Dec 2023, 10:03 AM                            20           160
# 4   23 Dec 2023, 10:04 AM                            20           160
# ..                    ...                           ...           ...
# 49   16 Apr 2024, 6:10 PM                            28            60
# 50   16 Apr 2024, 6:20 PM                            28            56
# 51   16 Apr 2024, 6:30 PM                            28            56
# 52   16 Apr 2024, 6:40 PM                            28            59
# 53   16 Apr 2024, 6:50 PM                            28            59
#
#    Phosphorous02 Nitrogen01 Nitrogen02 Potassium01 Potassium02  \
# 0            150        120        150         100          94
# 1            150        120        150         100          94
# 2            150        120        150         100          94
# 3            150        120        150         100          94
# 4            150        120        150         100          94
# ..           ...        ...        ...         ...         ...
# 49            63         83         53          72          76
# 50            62         83         57          72          78
# 51            63         83         57          72          78
# 52            63         83         57          72          78
# 53            63         83         57          72          78
#
#    Light Intensity Temp01 Hum01 Heat01 SoilM01 SoilM02  \
# 0              NaN   28.5   0.0   42.0     1.0     1.0
# 1              NaN   28.5   0.0   42.0     1.0     1.0
# 2              NaN   28.5   0.0   42.0     1.0     1.0
# 3              NaN   28.5   0.0   42.0     1.0     1.0
# 4              NaN   28.5  96.0   42.0     1.0     1.0
# ..             ...    ...   ...    ...     ...     ...
# 49              29   28.2    80     90       1       1
# 50              29   29.3    78     91       1       1
# 51              28   29.1    81     91       1       1
# 52              28   28.2    86     90       1       1
# 53              27   28.2    84     91       1       1
#
#    Grams of Compost Harvested Buzzer Compost Notes pH Rod 1 pH Rod 2
# 0                         NaN    NaN           NaN      NaN      NaN
# 1                         NaN    NaN           NaN      NaN      NaN
# 2                         NaN    NaN           NaN      NaN      NaN
# 3                         NaN    NaN           NaN      NaN      NaN
# 4                         NaN    NaN           NaN      NaN      NaN
# ..                        ...    ...           ...      ...      ...
# 49                        NaN   0.00           NaN   197.40   200.10
# 50                        NaN   0.00           NaN   184.16   200.96
# 51                        NaN   0.00           NaN   201.29   200.60
# 52                        NaN   0.00           NaN   197.65   200.57
# 53                        NaN   0.00           NaN   185.93   200.38
#
# [3636 rows x 19 columns]

# %%
df.shape
# Out:
# (3636, 19)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3636 entries, 0 to 53
# Data columns (total 19 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Timestamp                      3477 non-null   object
#  1   Number of Worms (non-counted)  2701 non-null   object
#  2   Phosphorous01                  3263 non-null   object
#  3   Phosphorous02                  3263 non-null   object
#  4   Nitrogen01                     3263 non-null   object
#  5   Nitrogen02                     3263 non-null   object
#  6   Potassium01                    3263 non-null   object
#  7   Potassium02                    3263 non-null   object
#  8   Light Intensity                109 non-null    object
#  9   Temp01                         2907 non-null   object
#  10  Hum01                          3049 non-null   object
#  11  Heat01                         2907 non-null   object
#  12  SoilM01                        2481 non-null   object
#  13  SoilM02                        2481 non-null   object
#  14  Grams of Compost Harvested     4 non-null      object
#  15  Buzzer                         2141 non-null   object
#  16  Compost Notes                  1 non-null      object
#  17  pH Rod 1                       109 non-null    object
#  18  pH Rod 2                       109 non-null    object
# dtypes: object(19)
# memory usage: 568.1+ KB

# %% [markdown]
# ### Exploring objects

# %%
#Exploring grams of compost harvest but its not very useful to analyse  as there are too many columns with null values
#Since compost notes only has 1 value, we will not explore it too

label_freq = df['Grams of Compost Harvested'].value_counts() / len(df)
fig = label_freq.sort_values(ascending=False).plot.bar()

fig.axhline(y=0.05, color='red')

fig.set_ylabel('Percentage of items in each category')
fig.set_xlabel('Variable: Grams of Compost Harvested')
fig.set_title('Rare Categories')
plt.show()

# %%
#Exporing number of worms 
#If using the column, clean to remove the word in the bracket and convert the 14.0 to 14.
label_freq = df['Number of Worms (non-counted)'].value_counts() / len(df)
fig = label_freq.sort_values(ascending=False).plot.bar()

fig.axhline(y=0.05, color='red')

fig.set_ylabel('Percentage of items in each category')
fig.set_xlabel('Variable: Num. of worms')
fig.set_title('Rare Categories')
plt.show()

# %%
#Exploring Buzzer
label_freq = df['Buzzer'].value_counts() / len(df)
fig = label_freq.sort_values(ascending=False).plot.bar()

fig.axhline(y=0.05, color='red')

fig.set_ylabel('Percentage of items in each category')
fig.set_xlabel('Variable: Buzzer')
fig.set_title('Rare Categories')
plt.show()

# %% [markdown]
# ### Exploring float variables

# %%
# drop rows with no npk values
df = df.dropna(subset=['Nitrogen01']) 

# Convert List of columns to float
columns_to_convert = ['Phosphorous01', 'Phosphorous02', 'Nitrogen01', 'Nitrogen02', 
                      'Potassium01', 'Potassium02', 'Temp01', 'Hum01', 'Heat01', 
                      'SoilM01', 'SoilM02']

# Convert columns to float
for col in columns_to_convert:
    # Convert non-positive values (such as "?" and negative numbers) with NaN
    df[col] = pd.to_numeric(df[col], errors='coerce')

df
# Out:
# C:\Users\fionn\AppData\Local\Temp\ipykernel_15380\1165375493.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = pd.to_numeric(df[col], errors='coerce')
#                 Timestamp Number of Worms (non-counted)  Phosphorous01  \
# 0   23 Dec 2023, 10:00 AM                            20          160.0
# 1   23 Dec 2023, 10:01 AM                            20          160.0
# 2   23 Dec 2023, 10:02 AM                            20          160.0
# 3   23 Dec 2023, 10:03 AM                            20          160.0
# 4   23 Dec 2023, 10:04 AM                            20          160.0
# ..                    ...                           ...            ...
# 49   16 Apr 2024, 6:10 PM                            28           60.0
# 50   16 Apr 2024, 6:20 PM                            28           56.0
# 51   16 Apr 2024, 6:30 PM                            28           56.0
# 52   16 Apr 2024, 6:40 PM                            28           59.0
# 53   16 Apr 2024, 6:50 PM                            28           59.0
#
#     Phosphorous02  Nitrogen01  Nitrogen02  Potassium01  Potassium02  \
# 0           150.0       120.0       150.0        100.0         94.0
# 1           150.0       120.0       150.0        100.0         94.0
# 2           150.0       120.0       150.0        100.0         94.0
# 3           150.0       120.0       150.0        100.0         94.0
# 4           150.0       120.0       150.0        100.0         94.0
# ..            ...         ...         ...          ...          ...
# 49           63.0        83.0        53.0         72.0         76.0
# 50           62.0        83.0        57.0         72.0         78.0
# 51           63.0        83.0        57.0         72.0         78.0
# 52           63.0        83.0        57.0         72.0         78.0
# 53           63.0        83.0        57.0         72.0         78.0
#
#    Light Intensity  Temp01  Hum01  Heat01  SoilM01  SoilM02  \
# 0              NaN    28.5    0.0    42.0      1.0      1.0
# 1              NaN    28.5    0.0    42.0      1.0      1.0
# 2              NaN    28.5    0.0    42.0      1.0      1.0
# 3              NaN    28.5    0.0    42.0      1.0      1.0
# 4              NaN    28.5   96.0    42.0      1.0      1.0
# ..             ...     ...    ...     ...      ...      ...
# 49              29    28.2   80.0    90.0      1.0      1.0
# 50              29    29.3   78.0    91.0      1.0      1.0
# 51              28    29.1   81.0    91.0      1.0      1.0
# 52              28    28.2   86.0    90.0      1.0      1.0
# 53              27    28.2   84.0    91.0      1.0      1.0
#
#    Grams of Compost Harvested Buzzer Compost Notes pH Rod 1 pH Rod 2
# 0                         NaN    NaN           NaN      NaN      NaN
# 1                         NaN    NaN           NaN      NaN      NaN
# 2                         NaN    NaN           NaN      NaN      NaN
# 3                         NaN    NaN           NaN      NaN      NaN
# 4                         NaN    NaN           NaN      NaN      NaN
# ..                        ...    ...           ...      ...      ...
# 49                        NaN   0.00           NaN   197.40   200.10
# 50                        NaN   0.00           NaN   184.16   200.96
# 51                        NaN   0.00           NaN   201.29   200.60
# 52                        NaN   0.00           NaN   197.65   200.57
# 53                        NaN   0.00           NaN   185.93   200.38
#
# [3263 rows x 19 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3263 entries, 0 to 53
# Data columns (total 19 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Timestamp                      3263 non-null   object
#  1   Number of Worms (non-counted)  2701 non-null   object
#  2   Phosphorous01                  2790 non-null   float64
#  3   Phosphorous02                  2790 non-null   float64
#  4   Nitrogen01                     2790 non-null   float64
#  5   Nitrogen02                     2790 non-null   float64
#  6   Potassium01                    2790 non-null   float64
#  7   Potassium02                    2790 non-null   float64
#  8   Light Intensity                109 non-null    object
#  9   Temp01                         2693 non-null   float64
#  10  Hum01                          2693 non-null   float64
#  11  Heat01                         2693 non-null   float64
#  12  SoilM01                        2403 non-null   float64
#  13  SoilM02                        2403 non-null   float64
#  14  Grams of Compost Harvested     4 non-null      object
#  15  Buzzer                         1927 non-null   object
#  16  Compost Notes                  1 non-null      object
#  17  pH Rod 1                       109 non-null    object
#  18  pH Rod 2                       109 non-null    object
# dtypes: float64(11), object(8)
# memory usage: 509.8+ KB

# %%
def diagnostic_plots(df, variable):
    
    plt.figure(figsize=(15,6))
    plt.subplot(1, 3, 1)
    plt.rcParams["patch.edgecolor"] = "none"
    sns.histplot(df[variable], bins=30, kde = True, stat ="density", kde_kws=dict(cut = 3),alpha = 0.30)
    plt.title('Histogram')

    plt.subplot(1, 3, 2)
    stats.probplot(df[variable], dist="norm", plot=plt)
    
    plt.subplot(1, 3, 3)
    sns.boxplot(y=df[variable])

    plt.show()
    
    # Count outliers using IQR method
    Q1 = df[variable].quantile(0.25)
    Q3 = df[variable].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    outliers = df[(df[variable] < lower_bound) | (df[variable] > upper_bound)]

    print(f'Number of outliers in {variable}: {len(outliers)}')
    
diagnostic_plots(df, 'Phosphorous01')
# Out:
# Number of outliers in Phosphorous01: 172

# %%
diagnostic_plots(df, 'Phosphorous02')
# Out:
# Number of outliers in Phosphorous02: 173

# %%
diagnostic_plots(df, 'Nitrogen01')
# Out:
# Number of outliers in Nitrogen01: 62

# %%
diagnostic_plots(df, 'Nitrogen02')
# Out:
# Number of outliers in Nitrogen02: 159

# %%
diagnostic_plots(df, 'Potassium01')
# Out:
# Number of outliers in Potassium01: 51

# %%
diagnostic_plots(df, 'Potassium02')
# Out:
# Number of outliers in Potassium02: 50

# %%
diagnostic_plots(df, 'Temp01')
# Out:
# Number of outliers in Temp01: 39

# %%
diagnostic_plots(df, 'Hum01')
# Out:
# Number of outliers in Hum01: 320

# %%
diagnostic_plots(df, 'Heat01')
# Out:
# Number of outliers in Heat01: 607

# %%
diagnostic_plots(df, 'SoilM01')
# Out:
# Number of outliers in SoilM01: 445

# %%
diagnostic_plots(df, 'SoilM02')
# Out:
# Number of outliers in SoilM02: 151

# %% [markdown]
# ### Relationship between variables

# %%
#Understanding the correlation of variables by showing the correlation matrix on a heatmap 
df_num = df.select_dtypes(['float64']).copy()

# Compute the correlation matrix
correlation_matrix = df_num.corr()

# Set up the matplotlib figure
plt.figure(figsize=(16, 16))

# Create a heatmap using seaborn
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=.5)

# Show the plot
plt.title('Correlation Heatmap of Macpherson Rack 01 Numerical Features')
plt.show()

# %%
# Calculate summary statistics for each feature
summary_stats = {}
for column in df_num:
    stats = df.groupby('Buzzer')[column].agg(['mean', 'median', 'std'])
    summary_stats[column] = stats

# Display summary statistics for each feature
for column, stats in summary_stats.items():
    print(f"Summary statistics for '{column}':")
    print(stats)
    print()
# Out:
# Summary statistics for 'Phosphorous01':
#               mean  median        std
# Buzzer
# 0.00     57.740000    58.0   1.208980
# 1.00     56.000000    56.0   0.000000
# Off     152.245258   158.0  57.920384
# On      161.122340   161.0  17.567317
#
# Summary statistics for 'Phosphorous02':
#               mean  median        std
# Buzzer
# 0.00     62.440000    63.0   1.473023
# 1.00     63.000000    63.0   0.000000
# Off     152.950578   159.0  58.385331
# On      162.377660   160.0  18.764255
#
# Summary statistics for 'Nitrogen01':
#               mean  median        std
# Buzzer
# 0.00     82.720000    83.0   0.701020
# 1.00     83.000000    83.0   0.000000
# Off     156.308131   164.0  57.833580
# On      165.404255   167.0  16.617637
#
# Summary statistics for 'Nitrogen02':
#               mean  median        std
# Buzzer
# 0.00     53.180000    53.0   1.494070
# 1.00     56.000000    56.0   0.000000
# Off     156.598927   163.0  57.492190
# On      165.367021   159.5  17.001994
#
# Summary statistics for 'Potassium01':
#               mean  median        std
# Buzzer
# 0.00     72.000000    72.0   0.000000
# 1.00     72.000000    72.0   0.000000
# Off     155.151073   161.5  58.570526
# On      163.542553   162.0  17.412372
#
# Summary statistics for 'Potassium02':
#               mean  median        std
# Buzzer
# 0.00     75.340000    76.0   1.880187
# 1.00     76.500000    76.5   0.577350
# Off     155.704708   163.0  58.666576
# On      166.771277   167.0  19.302152
#
# Summary statistics for 'Temp01':
#              mean  median       std
# Buzzer
# 0.00    29.818000   29.20  1.489650
# 1.00    30.750000   30.75  0.129099
# Off     31.698872   32.10  2.006819
# On      28.704255   27.40  3.062606
#
# Summary statistics for 'Hum01':
#              mean  median        std
# Buzzer
# 0.00    79.620000    79.5   5.480541
# 1.00    76.500000    76.5   2.886751
# Off     94.239169    95.0  12.119913
# On      96.069149    96.0   2.134641
#
# Summary statistics for 'Heat01':
#              mean  median       std
# Buzzer
# 0.00    91.340000    91.0  1.171254
# 1.00    91.250000    91.0  1.258306
# Off     42.503858    42.0  7.155103
# On      42.117021    42.0  0.691528
#
# Summary statistics for 'SoilM01':
#             mean  median       std
# Buzzer
# 0.00    1.000000     1.0  0.000000
# 1.00    0.000000     0.0  0.000000
# Off     0.957295     1.0  0.202262
# On      0.313830     0.0  0.465287
#
# Summary statistics for 'SoilM02':
#             mean  median       std
# Buzzer
# 0.00    1.000000     1.0  0.000000
# 1.00    0.000000     0.0  0.000000
# Off     0.997865     1.0  0.046176
# On      0.250000     0.0  0.434169

# %%
# Exploring relationship between variables
#Phosphorus
plt.figure(figsize=(8, 6))
plt.scatter(df['Phosphorous01'], df['Phosphorous02'])
plt.title('Scatter Plot of Phosphorous01 vs Phosphorous02')
plt.xlabel('Phosphorous01')
plt.ylabel('Phosphorous02')
plt.grid(True)
plt.show()

# %%
#Nitrogen
plt.figure(figsize=(8, 6))
plt.scatter(df['Nitrogen01'], df['Nitrogen02'])
plt.title('Scatter Plot of Nitrogen01 vs Nitrogen02')
plt.xlabel('Nitrogen01')
plt.ylabel('Nitrogen02')
plt.grid(True)
plt.show()

# %%
#Potassium
plt.figure(figsize=(8, 6))
plt.scatter(df['Potassium01'], df['Potassium02'])
plt.title('Scatter Plot of Potassium01 vs Potassium02')
plt.xlabel('Potassium01')
plt.ylabel('Potassium02')
plt.grid(True)
plt.show()

# %%
#Temp01 vs Heat01
plt.figure(figsize=(8, 6))
plt.scatter(df['Temp01'], df['Heat01'])
plt.title('Scatter Plot of Temp01 vs Heat01')
plt.xlabel('Temp01')
plt.ylabel('Heat01')
plt.grid(True)
plt.show()

# %% [markdown]
# ### 3. Cleaning

# %%
#Dropping irrelevant features 
df = df.drop(columns=['Number of Worms (non-counted)', 'Light Intensity', 'Grams of Compost Harvested',
                                'Buzzer', 'Compost Notes', 'pH Rod 1', 'pH Rod 2'])
df
# Out:
#                 Timestamp  Phosphorous01  Phosphorous02  Nitrogen01  \
# 0   23 Dec 2023, 10:00 AM          160.0          150.0       120.0
# 1   23 Dec 2023, 10:01 AM          160.0          150.0       120.0
# 2   23 Dec 2023, 10:02 AM          160.0          150.0       120.0
# 3   23 Dec 2023, 10:03 AM          160.0          150.0       120.0
# 4   23 Dec 2023, 10:04 AM          160.0          150.0       120.0
# ..                    ...            ...            ...         ...
# 49   16 Apr 2024, 6:10 PM           60.0           63.0        83.0
# 50   16 Apr 2024, 6:20 PM           56.0           62.0        83.0
# 51   16 Apr 2024, 6:30 PM           56.0           63.0        83.0
# 52   16 Apr 2024, 6:40 PM           59.0           63.0        83.0
# 53   16 Apr 2024, 6:50 PM           59.0           63.0        83.0
#
#     Nitrogen02  Potassium01  Potassium02  Temp01  Hum01  Heat01  SoilM01  \
# 0        150.0        100.0         94.0    28.5    0.0    42.0      1.0
# 1        150.0        100.0         94.0    28.5    0.0    42.0      1.0
# 2        150.0        100.0         94.0    28.5    0.0    42.0      1.0
# 3        150.0        100.0         94.0    28.5    0.0    42.0      1.0
# 4        150.0        100.0         94.0    28.5   96.0    42.0      1.0
# ..         ...          ...          ...     ...    ...     ...      ...
# 49        53.0         72.0         76.0    28.2   80.0    90.0      1.0
# 50        57.0         72.0         78.0    29.3   78.0    91.0      1.0
# 51        57.0         72.0         78.0    29.1   81.0    91.0      1.0
# 52        57.0         72.0         78.0    28.2   86.0    90.0      1.0
# 53        57.0         72.0         78.0    28.2   84.0    91.0      1.0
#
#     SoilM02
# 0       1.0
# 1       1.0
# 2       1.0
# 3       1.0
# 4       1.0
# ..      ...
# 49      1.0
# 50      1.0
# 51      1.0
# 52      1.0
# 53      1.0
#
# [3263 rows x 12 columns]

# %%
#Dropping rows with null npk values
df['Timestamp']
# Out:
# 0     23 Dec 2023, 10:00 AM
# 1     23 Dec 2023, 10:01 AM
# 2     23 Dec 2023, 10:02 AM
# 3     23 Dec 2023, 10:03 AM
# 4     23 Dec 2023, 10:04 AM
#               ...
# 49     16 Apr 2024, 6:10 PM
# 50     16 Apr 2024, 6:20 PM
# 51     16 Apr 2024, 6:30 PM
# 52     16 Apr 2024, 6:40 PM
# 53     16 Apr 2024, 6:50 PM
# Name: Timestamp, Length: 3263, dtype: object

# %%
# Convert 'Timestamp' column to datetime
df['Timestamp'] = pd.to_datetime(df['Timestamp'], format='%d %b %Y, %I:%M %p')

df
# Out:
#              Timestamp  Phosphorous01  Phosphorous02  Nitrogen01  Nitrogen02  \
# 0  2023-12-23 10:00:00          160.0          150.0       120.0       150.0
# 1  2023-12-23 10:01:00          160.0          150.0       120.0       150.0
# 2  2023-12-23 10:02:00          160.0          150.0       120.0       150.0
# 3  2023-12-23 10:03:00          160.0          150.0       120.0       150.0
# 4  2023-12-23 10:04:00          160.0          150.0       120.0       150.0
# ..                 ...            ...            ...         ...         ...
# 49 2024-04-16 18:10:00           60.0           63.0        83.0        53.0
# 50 2024-04-16 18:20:00           56.0           62.0        83.0        57.0
# 51 2024-04-16 18:30:00           56.0           63.0        83.0        57.0
# 52 2024-04-16 18:40:00           59.0           63.0        83.0        57.0
# 53 2024-04-16 18:50:00           59.0           63.0        83.0        57.0
#
#     Potassium01  Potassium02  Temp01  Hum01  Heat01  SoilM01  SoilM02
# 0         100.0         94.0    28.5    0.0    42.0      1.0      1.0
# 1         100.0         94.0    28.5    0.0    42.0      1.0      1.0
# 2         100.0         94.0    28.5    0.0    42.0      1.0      1.0
# 3         100.0         94.0    28.5    0.0    42.0      1.0      1.0
# 4         100.0         94.0    28.5   96.0    42.0      1.0      1.0
# ..          ...          ...     ...    ...     ...      ...      ...
# 49         72.0         76.0    28.2   80.0    90.0      1.0      1.0
# 50         72.0         78.0    29.3   78.0    91.0      1.0      1.0
# 51         72.0         78.0    29.1   81.0    91.0      1.0      1.0
# 52         72.0         78.0    28.2   86.0    90.0      1.0      1.0
# 53         72.0         78.0    28.2   84.0    91.0      1.0      1.0
#
# [3263 rows x 12 columns]

# %%
#Creating features with timestamp
df['Time'] = df['Timestamp'].dt.time
df['Day'] = df['Timestamp'].dt.day

df
# Out:
#              Timestamp  Phosphorous01  Phosphorous02  Nitrogen01  Nitrogen02  \
# 0  2023-12-23 10:00:00          160.0          150.0       120.0       150.0
# 1  2023-12-23 10:01:00          160.0          150.0       120.0       150.0
# 2  2023-12-23 10:02:00          160.0          150.0       120.0       150.0
# 3  2023-12-23 10:03:00          160.0          150.0       120.0       150.0
# 4  2023-12-23 10:04:00          160.0          150.0       120.0       150.0
# ..                 ...            ...            ...         ...         ...
# 49 2024-04-16 18:10:00           60.0           63.0        83.0        53.0
# 50 2024-04-16 18:20:00           56.0           62.0        83.0        57.0
# 51 2024-04-16 18:30:00           56.0           63.0        83.0        57.0
# 52 2024-04-16 18:40:00           59.0           63.0        83.0        57.0
# 53 2024-04-16 18:50:00           59.0           63.0        83.0        57.0
#
#     Potassium01  Potassium02  Temp01  Hum01  Heat01  SoilM01  SoilM02  \
# 0         100.0         94.0    28.5    0.0    42.0      1.0      1.0
# 1         100.0         94.0    28.5    0.0    42.0      1.0      1.0
# 2         100.0         94.0    28.5    0.0    42.0      1.0      1.0
# 3         100.0         94.0    28.5    0.0    42.0      1.0      1.0
# 4         100.0         94.0    28.5   96.0    42.0      1.0      1.0
# ..          ...          ...     ...    ...     ...      ...      ...
# 49         72.0         76.0    28.2   80.0    90.0      1.0      1.0
# 50         72.0         78.0    29.3   78.0    91.0      1.0      1.0
# 51         72.0         78.0    29.1   81.0    91.0      1.0      1.0
# 52         72.0         78.0    28.2   86.0    90.0      1.0      1.0
# 53         72.0         78.0    28.2   84.0    91.0      1.0      1.0
#
#         Time  Day
# 0   10:00:00   23
# 1   10:01:00   23
# 2   10:02:00   23
# 3   10:03:00   23
# 4   10:04:00   23
# ..       ...  ...
# 49  18:10:00   16
# 50  18:20:00   16
# 51  18:30:00   16
# 52  18:40:00   16
# 53  18:50:00   16
#
# [3263 rows x 14 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3263 entries, 0 to 53
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Timestamp      3263 non-null   datetime64[ns]
#  1   Phosphorous01  2790 non-null   float64
#  2   Phosphorous02  2790 non-null   float64
#  3   Nitrogen01     2790 non-null   float64
#  4   Nitrogen02     2790 non-null   float64
#  5   Potassium01    2790 non-null   float64
#  6   Potassium02    2790 non-null   float64
#  7   Temp01         2693 non-null   float64
#  8   Hum01          2693 non-null   float64
#  9   Heat01         2693 non-null   float64
#  10  SoilM01        2403 non-null   float64
#  11  SoilM02        2403 non-null   float64
#  12  Time           3263 non-null   object
#  13  Day            3263 non-null   int64
# dtypes: datetime64[ns](1), float64(11), int64(1), object(1)
# memory usage: 382.4+ KB

# %%
df
# Out:
#              Timestamp  Phosphorous01  Phosphorous02  Nitrogen01  Nitrogen02  \
# 0  2023-12-23 10:00:00          160.0          150.0       120.0       150.0
# 1  2023-12-23 10:01:00          160.0          150.0       120.0       150.0
# 2  2023-12-23 10:02:00          160.0          150.0       120.0       150.0
# 3  2023-12-23 10:03:00          160.0          150.0       120.0       150.0
# 4  2023-12-23 10:04:00          160.0          150.0       120.0       150.0
# ..                 ...            ...            ...         ...         ...
# 49 2024-04-16 18:10:00           60.0           63.0        83.0        53.0
# 50 2024-04-16 18:20:00           56.0           62.0        83.0        57.0
# 51 2024-04-16 18:30:00           56.0           63.0        83.0        57.0
# 52 2024-04-16 18:40:00           59.0           63.0        83.0        57.0
# 53 2024-04-16 18:50:00           59.0           63.0        83.0        57.0
#
#     Potassium01  Potassium02  Temp01  Hum01  Heat01  SoilM01  SoilM02  \
# 0         100.0         94.0    28.5    0.0    42.0      1.0      1.0
# 1         100.0         94.0    28.5    0.0    42.0      1.0      1.0
# 2         100.0         94.0    28.5    0.0    42.0      1.0      1.0
# 3         100.0         94.0    28.5    0.0    42.0      1.0      1.0
# 4         100.0         94.0    28.5   96.0    42.0      1.0      1.0
# ..          ...          ...     ...    ...     ...      ...      ...
# 49         72.0         76.0    28.2   80.0    90.0      1.0      1.0
# 50         72.0         78.0    29.3   78.0    91.0      1.0      1.0
# 51         72.0         78.0    29.1   81.0    91.0      1.0      1.0
# 52         72.0         78.0    28.2   86.0    90.0      1.0      1.0
# 53         72.0         78.0    28.2   84.0    91.0      1.0      1.0
#
#         Time  Day
# 0   10:00:00   23
# 1   10:01:00   23
# 2   10:02:00   23
# 3   10:03:00   23
# 4   10:04:00   23
# ..       ...  ...
# 49  18:10:00   16
# 50  18:20:00   16
# 51  18:30:00   16
# 52  18:40:00   16
# 53  18:50:00   16
#
# [3263 rows x 14 columns]

# %% [markdown]
# ### Treating missing and inaccurate data

# %%
plt.figure(figsize=(12,8))  # Set the figure size

test = df[df['Day'] <= 6]
# Plot phosphorus01 against time
plt.plot(test['Timestamp'], test['Phosphorous01'], color='blue', linestyle='-')

# Set labels and title
plt.xlabel('Time')
plt.ylabel('Phosphorus01')
plt.title('Phosphorus01 over Time')

# Rotate x-axis labels for better readability if needed
plt.xticks(rotation=45)

# Show grid
plt.grid(True)

# Show plot
plt.show()

# %%
# # Define the time period of sensor malfunction
start_time = pd.to_datetime('13:33:00').time()
end_time = pd.to_datetime('13:38:00').time()

# Flag the data points where day is 6th or 14th and time is between 13:33:00 and 13:38:00
sensor_malfunction = ((df['Day'] == 6) | (df['Day'] == 14)) & (df['Time'].apply(lambda x: x >= start_time) & (df['Time'].apply(lambda x: x <= end_time)))

NPK_columns = ['Phosphorous01', 'Phosphorous02', 'Nitrogen01', 'Nitrogen02', 'Potassium01' ,'Potassium02']
for column in NPK_columns:
    # Convert negative values to NaN
    df.loc[df[column] <= 0, column] = np.nan
    df.loc[sensor_malfunction, column] = np.nan
    
df.describe()
# Out:
#        Phosphorous01  Phosphorous02   Nitrogen01   Nitrogen02  Potassium01  \
# count    2721.000000    2720.000000  2722.000000  2722.000000  2721.000000
# mean      157.287394     155.350000   150.785452   157.292799   145.076075
# std        25.083883      25.166447    27.951477    25.788425    34.626851
# min        54.000000      56.000000    81.000000    51.000000    69.000000
# 25%       146.000000     146.000000   120.000000   150.000000   100.000000
# 50%       160.000000     150.000000   151.000000   155.000000   150.000000
# 75%       169.000000     173.000000   174.000000   172.000000   173.000000
# max       201.000000     201.000000   201.000000   201.000000   201.000000
#
#        Potassium02       Temp01        Hum01       Heat01      SoilM01  \
# count  2721.000000  2693.000000  2693.000000  2693.000000  2403.000000
# mean    144.236310    30.245971    88.678797    42.415893     0.814815
# std      36.859217     4.348887    24.049565    14.913747     0.388529
# min      69.000000     0.000000     0.000000     0.000000     0.000000
# 25%      94.000000    28.500000    94.000000    42.000000     1.000000
# 50%     151.000000    31.700000    95.000000    42.000000     1.000000
# 75%     174.000000    32.400000    97.000000    43.000000     1.000000
# max     201.000000    36.100000   100.000000    97.000000     1.000000
#
#            SoilM02          Day
# count  2403.000000  3263.000000
# mean      0.937162    11.503524
# std       0.242722     7.251159
# min       0.000000     5.000000
# 25%       1.000000     5.000000
# 50%       1.000000     6.000000
# 75%       1.000000    16.000000
# max       1.000000    23.000000

# %%
# test moving average function
def moving_average(df):
    data = df.copy()
    for column in columns_to_convert:
        window_size = 3
        moving_avg = data[column].rolling(window=window_size, min_periods=1).mean()

        data[column] = np.where(data[column].isnull(), moving_avg, data[column])

    plt.figure(figsize=(12,8))

    test = data[data['Day'] <= 6]

    plt.plot(test['Timestamp'], test['Phosphorous01'], color='blue', linestyle='-')

    # Set labels and title
    plt.xlabel('Time')
    plt.ylabel('Phosphorus01')
    plt.title('Phosphorus01 over Time')

    plt.xticks(rotation=45)

    plt.grid(True)

    plt.show()
    return data

avg = moving_average(df)
avg.describe()
# Out:
#        Phosphorous01  Phosphorous02   Nitrogen01   Nitrogen02  Potassium01  \
# count    2747.000000    2747.000000  2748.000000  2748.000000  2747.000000
# mean      157.282672     155.319985   150.799491   157.349891   145.114853
# std        25.152725      25.249979    27.858097    25.721400    34.529229
# min        54.000000      56.000000    81.000000    51.000000    69.000000
# 25%       147.000000     146.000000   120.000000   150.000000   100.000000
# 50%       160.000000     150.000000   151.000000   155.000000   150.000000
# 75%       169.000000     173.000000   174.000000   172.000000   173.000000
# max       201.000000     201.000000   201.000000   201.000000   201.000000
#
#        Potassium02       Temp01        Hum01       Heat01      SoilM01  \
# count  2747.000000  2699.000000  2699.000000  2699.000000  2427.000000
# mean    144.316527    30.223953    88.624120    42.321601     0.814174
# std      36.759268     4.422051    24.145561    15.030545     0.389046
# min      69.000000     0.000000     0.000000     0.000000     0.000000
# 25%      94.000000    28.500000    94.000000    42.000000     1.000000
# 50%     151.000000    31.700000    95.000000    42.000000     1.000000
# 75%     174.000000    32.400000    97.000000    43.000000     1.000000
# max     201.000000    36.100000   100.000000    97.000000     1.000000
#
#            SoilM02          Day
# count  2427.000000  3263.000000
# mean      0.935929    11.503524
# std       0.244298     7.251159
# min       0.000000     5.000000
# 25%       1.000000     5.000000
# 50%       1.000000     6.000000
# 75%       1.000000    16.000000
# max       1.000000    23.000000

# %%
# test interpolation
def interpolation(df):
    data = df.copy()
    for column in columns_to_convert:
        data[column] = data[column].interpolate(method='linear')
    plt.figure(figsize=(12,8))

    test = data[data['Day'] <= 6]
    plt.plot(test['Timestamp'], test['Phosphorous01'], color='blue', linestyle='-')

    plt.xlabel('Time')
    plt.ylabel('Phosphorus01')
    plt.title('Phosphorus01 over Time')

    plt.xticks(rotation=45)
    
    plt.grid(True)

    plt.show()
    return data

interpolate = interpolation(df)
interpolate.describe()
# Out:
#        Phosphorous01  Phosphorous02   Nitrogen01   Nitrogen02  Potassium01  \
# count    3263.000000    3263.000000  3263.000000  3263.000000  3263.000000
# mean      157.982685     156.155378   151.569261   159.810297   148.187404
# std        24.397069      24.641029    26.710845    24.938776    33.554888
# min        54.000000      56.000000    81.000000    51.000000    69.000000
# 25%       146.000000     146.000000   131.000000   150.000000   129.132867
# 50%       160.000000     150.000000   151.000000   159.000000   154.000000
# 75%       172.000000     173.417832   173.000000   176.000000   175.000000
# max       201.000000     201.000000   201.000000   201.000000   201.000000
#
#        Potassium02       Temp01        Hum01       Heat01      SoilM01  \
# count  3263.000000  3263.000000  3263.000000  3263.000000  3263.000000
# mean    146.808458    29.049923    87.346920    38.674839     0.792216
# std      35.224417     6.000248    24.876214    16.586586     0.375098
# min      69.000000     0.000000     0.000000     0.000000     0.000000
# 25%     123.000000    28.167017    94.000000    42.000000     0.794578
# 50%     155.000000    30.100000    95.000000    42.000000     1.000000
# 75%     174.000000    32.100000    98.000000    43.000000     1.000000
# max     201.000000    36.100000   100.000000    97.000000     1.000000
#
#            SoilM02          Day
# count  3263.000000  3263.000000
# mean      0.882317    11.503524
# std       0.282673     7.251159
# min       0.000000     5.000000
# 25%       1.000000     5.000000
# 50%       1.000000     6.000000
# 75%       1.000000    16.000000
# max       1.000000    23.000000

# %%
# test forward and backward fill 
def fill(df):
    data = df.copy()
    for column in columns_to_convert:
        data[column] = data[column].fillna(method='ffill').fillna(method='bfill')
    plt.figure(figsize=(12,8))

    test = data[data['Day'] <= 6]

    plt.plot(test['Timestamp'], test['Phosphorous01'], color='blue', linestyle='-')

    plt.xlabel('Time')
    plt.ylabel('Phosphorus01')
    plt.title('Phosphorus01 over Time')

    plt.xticks(rotation=45)

    plt.grid(True)

    plt.show()
    return data

filled = fill(df)
filled.describe()
# Out:
#        Phosphorous01  Phosphorous02   Nitrogen01   Nitrogen02  Potassium01  \
# count    3263.000000    3263.000000  3263.000000  3263.000000  3263.000000
# mean      158.104812     156.364082   149.101134   158.977015   145.517315
# std        24.219643      25.864747    26.406114    24.481423    34.428240
# min        54.000000      56.000000    81.000000    51.000000    69.000000
# 25%       147.000000     146.000000   120.000000   150.000000   100.000000
# 50%       160.000000     150.000000   147.000000   159.000000   149.000000
# 75%       171.000000     174.000000   170.000000   174.000000   175.000000
# max       201.000000     201.000000   201.000000   201.000000   201.000000
#
#        Potassium02       Temp01        Hum01       Heat01      SoilM01  \
# count  3263.000000  3263.000000  3263.000000  3263.000000  3263.000000
# mean    143.963530    28.351027    84.821024    35.006436     0.720809
# std      35.981255     8.414432    29.948973    21.047863     0.448670
# min      69.000000     0.000000     0.000000     0.000000     0.000000
# 25%      94.000000    28.500000    94.000000    42.000000     0.000000
# 50%     149.000000    30.400000    95.000000    42.000000     1.000000
# 75%     173.000000    32.400000    98.000000    43.000000     1.000000
# max     201.000000    36.100000   100.000000    97.000000     1.000000
#
#           SoilM02          Day
# count  3263.00000  3263.000000
# mean      0.81091    11.503524
# std       0.39164     7.251159
# min       0.00000     5.000000
# 25%       1.00000     5.000000
# 50%       1.00000     6.000000
# 75%       1.00000    16.000000
# max       1.00000    23.000000

# %%
# Chose interpolation in the end
df = interpolation(df)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3263 entries, 0 to 53
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Timestamp      3263 non-null   datetime64[ns]
#  1   Phosphorous01  3263 non-null   float64
#  2   Phosphorous02  3263 non-null   float64
#  3   Nitrogen01     3263 non-null   float64
#  4   Nitrogen02     3263 non-null   float64
#  5   Potassium01    3263 non-null   float64
#  6   Potassium02    3263 non-null   float64
#  7   Temp01         3263 non-null   float64
#  8   Hum01          3263 non-null   float64
#  9   Heat01         3263 non-null   float64
#  10  SoilM01        3263 non-null   float64
#  11  SoilM02        3263 non-null   float64
#  12  Time           3263 non-null   object
#  13  Day            3263 non-null   int64
# dtypes: datetime64[ns](1), float64(11), int64(1), object(1)
# memory usage: 382.4+ KB

# %% [markdown]
# ### 4. Getting average NPK and Moisture values

# %%
df['Mean_Phosphorous'] = df[['Phosphorous01', 'Phosphorous02']].mean(axis=1)
df['Mean_Nitrogen'] = df[['Nitrogen01', 'Nitrogen02']].mean(axis=1)
df['Mean_Potassium'] = df[['Potassium01', 'Potassium02']].mean(axis=1)
df['Mean_Moisture'] = df[['SoilM01', 'SoilM02']].mean(axis=1)
df['Mean_Moisture'] = df['Mean_Moisture'].replace(0.5, 1)
df = df.drop(columns = NPK_columns)
df = df.drop(columns = ['SoilM01', 'SoilM02'])
df.describe()
# Out:
#             Temp01        Hum01       Heat01          Day  Mean_Phosphorous  \
# count  3263.000000  3263.000000  3263.000000  3263.000000       3263.000000
# mean     29.049923    87.346920    38.674839    11.503524        157.069032
# std       6.000248    24.876214    16.586586     7.251159         22.589253
# min       0.000000     0.000000     0.000000     5.000000         55.000000
# 25%      28.167017    94.000000    42.000000     5.000000        150.500000
# 50%      30.100000    95.000000    42.000000     6.000000        155.000000
# 75%      32.100000    98.000000    43.000000    16.000000        170.000000
# max      36.100000   100.000000    97.000000    23.000000        200.000000
#
#        Mean_Nitrogen  Mean_Potassium  Mean_Moisture
# count    3263.000000     3263.000000    3263.000000
# mean      155.689779      147.497931       0.887220
# std        23.030885       32.960812       0.276193
# min        66.000000       69.000000       0.000000
# 25%       140.000000      126.769231       1.000000
# 50%       159.000000      159.000000       1.000000
# 75%       171.000000      171.500000       1.000000
# max       200.500000      199.000000       1.000000

# %% [markdown]
# ### 5. Preparing for Modelling

# %%
df = df.drop(columns=['Timestamp', "Time", "Day", "Heat01"])
for col in df.columns:
    df[col] = pd.to_numeric(df[col], errors='raise')
df.describe()
# Out:
#             Temp01        Hum01  Mean_Phosphorous  Mean_Nitrogen  \
# count  3263.000000  3263.000000       3263.000000    3263.000000
# mean     29.049923    87.346920        157.069032     155.689779
# std       6.000248    24.876214         22.589253      23.030885
# min       0.000000     0.000000         55.000000      66.000000
# 25%      28.167017    94.000000        150.500000     140.000000
# 50%      30.100000    95.000000        155.000000     159.000000
# 75%      32.100000    98.000000        170.000000     171.000000
# max      36.100000   100.000000        200.000000     200.500000
#
#        Mean_Potassium  Mean_Moisture
# count     3263.000000    3263.000000
# mean       147.497931       0.887220
# std         32.960812       0.276193
# min         69.000000       0.000000
# 25%        126.769231       1.000000
# 50%        159.000000       1.000000
# 75%        171.500000       1.000000
# max        199.000000       1.000000

# %%
correlation_matrix = df.corr()
colormap = plt.cm.BrBG
plt.figure(figsize=(16, 16))
sns.heatmap(correlation_matrix, annot=True, cmap="coolwarm", linewidths=.5)
plt.title('Correlation Heatmap of Macpherson Rack 01 Numerical Features')
plt.show()

# %%
nitro = df.copy()
nitro = nitro.drop(columns=['Mean_Phosphorous', 'Mean_Potassium'])
target_corr = nitro.corr()["Mean_Nitrogen"].sort_values()
corr_df = pd.DataFrame({"Mean_Nitrogen": target_corr})
plt.figure(figsize=(15,15))
plt.title('Correlation to Nitrogen', size=20)
ax = sns.heatmap(corr_df, cmap="coolwarm", annot=True)
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.show()

# %%
phos = df.copy()
phos = phos.drop(columns=['Mean_Nitrogen', 'Mean_Potassium'])
target_corr = phos.corr()["Mean_Phosphorous"].sort_values()
corr_df = pd.DataFrame({"Mean_Phosphorous": target_corr})
plt.figure(figsize=(15,15))
plt.title('Correlation to Phosphorous', size=20)
ax = sns.heatmap(corr_df, cmap="coolwarm", annot=True)
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.show()

# %%
pot = df.copy()
pot = pot.drop(columns=['Mean_Nitrogen', 'Mean_Phosphorous'])
target_corr = pot.corr()["Mean_Potassium"].sort_values()
corr_df = pd.DataFrame({"Mean_Potassium": target_corr})
plt.figure(figsize=(15,15))
plt.title('Correlation to Potassium', size=20)
ax = sns.heatmap(corr_df, cmap="coolwarm", annot=True)
bottom, top = ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
plt.show()

# %% [markdown]
# ### 6. Scaling

# %%
df_scaled = df.copy()
df_scaled = df_scaled.drop(columns=['Mean_Nitrogen', 'Mean_Potassium', 'Mean_Phosphorous'])
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df_scaled)
df_scaled = pd.DataFrame(df_scaled, columns = ['Temperature', 'Humidity', 'Moisture Presence'])
df_scaled
# Out:
#       Temperature  Humidity  Moisture Presence
# 0       -0.091664 -3.511801           0.408399
# 1       -0.091664 -3.511801           0.408399
# 2       -0.091664 -3.511801           0.408399
# 3       -0.091664 -3.511801           0.408399
# 4       -0.091664  0.347899           0.408399
# ...           ...       ...                ...
# 3258    -0.141670 -0.295384           0.408399
# 3259     0.041684 -0.375795           0.408399
# 3260     0.008347 -0.255179           0.408399
# 3261    -0.141670 -0.054153           0.408399
# 3262    -0.141670 -0.134564           0.408399
#
# [3263 rows x 3 columns]

# %% [markdown]
# ### 7. Modelling

# %%
y = df[['Mean_Nitrogen', 'Mean_Phosphorous', 'Mean_Potassium']]

# %%
X_train, X_test, y_train, y_test = train_test_split(df_scaled, y, test_size=0.2, random_state=42)

# %% [markdown]
# ### Random Forest

# %% [markdown]
# #### Baseline

# %%
models = {}
for nutrient in y_train.columns:
    model = RandomForestRegressor(random_state=42)
    model.fit(X_train, y_train[nutrient])
    models[nutrient] = model

# Testing models
y_pred = pd.DataFrame()
for nutrient, model in models.items():
    y_pred[nutrient] = model.predict(X_test)

# Evaluating models
for nutrient, model in models.items():
    mae = mean_absolute_error(y_test[nutrient], y_pred[nutrient])
    r2 = r2_score(y_test[nutrient], y_pred[nutrient])
    print(f'Mean Absolute Error for {nutrient}: {mae}')
    print(f'R-squared for {nutrient}: {r2}\n')

# %% [markdown]
# #### GridSearch #1

# %%
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 5, 10],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# Dictionary to store best models
best_models = {}

# Train separate Random Forest models for each nutrient with GridSearchCV
for nutrient in y_train.columns:
    model = RandomForestRegressor(random_state=42)
    grid_search = GridSearchCV(estimator=model, param_grid=param_grid, scoring='neg_mean_absolute_error', cv=5)
    grid_search.fit(X_train, y_train[nutrient])
    best_models[nutrient] = grid_search.best_estimator_
    print(f"Best parameters for {nutrient}: {grid_search.best_params_}")

# %%
# Best hyperparameters for each nutrient
best_params = {
    'Mean_Nitrogen': {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100},
    'Mean_Phosphorous': {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100},
    'Mean_Potassium': {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 300}
}

# Instantiate separate SVR models for each nutrient with best parameters
models = {}
for nutrient in y_train.columns:
    model = RandomForestRegressor(**best_params[nutrient], random_state=42)
    model.fit(X_train, y_train[nutrient])
    models[nutrient] = model

# Evaluate the models
y_pred = pd.DataFrame()
for nutrient, model in models.items():
    y_pred[nutrient] = model.predict(X_test)

# Evaluate the models
for nutrient, model in models.items():
    mae = mean_absolute_error(y_test[nutrient], y_pred[nutrient])
    r2 = r2_score(y_test[nutrient], y_pred[nutrient])
    print(f'Mean Absolute Error for {nutrient}: {mae}')
    print(f'R-squared for {nutrient}: {r2}\n')

# %% [markdown]
# #### GridSearch #2

# %%
param_grid = {
    'n_estimators': [100, 250, 300],
    'max_depth': [9,10,11],
    'min_samples_split': [2, 3],
    'min_samples_leaf': [1]
}

# Dictionary to store best models
best_models = {}

# Train separate Random Forest models for each nutrient with GridSearchCV
for nutrient in y_train.columns:
    model = RandomForestRegressor(random_state=42)
    grid_search = GridSearchCV(estimator=model, param_grid=param_grid, scoring='neg_mean_absolute_error', cv=5)
    grid_search.fit(X_train, y_train[nutrient])
    best_models[nutrient] = grid_search.best_estimator_
    print(f"Best parameters for {nutrient}: {grid_search.best_params_}")

# %%
# Best hyperparameters for each nutrient
best_params = {
    'Mean_Nitrogen': {'max_depth': 9, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 250},
    'Mean_Phosphorous': {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100},
    'Mean_Potassium': {'max_depth': 9, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 300}
}

# Instantiate separate SVR models for each nutrient with best parameters
models = {}
for nutrient in y_train.columns:
    model = RandomForestRegressor(**best_params[nutrient], random_state=42)
    model.fit(X_train, y_train[nutrient])
    models[nutrient] = model

# Evaluate the models
y_pred = pd.DataFrame()
for nutrient, model in models.items():
    y_pred[nutrient] = model.predict(X_test)

# Evaluate the models
for nutrient, model in models.items():
    mae = mean_absolute_error(y_test[nutrient], y_pred[nutrient])
    r2 = r2_score(y_test[nutrient], y_pred[nutrient])
    print(f'Mean Absolute Error for {nutrient}: {mae}')
    print(f'R-squared for {nutrient}: {r2}\n')

# %% [markdown]
# #### Gridsearch #3

# %%
param_grid = {
    'n_estimators': [100, 150, 250, 300],
    'max_depth': [9,10,11],
    'min_samples_split': [2, 3],
    'min_samples_leaf': [1]
}

# Dictionary to store best models
best_models = {}

# Train separate Random Forest models for each nutrient with GridSearchCV
for nutrient in y_train.columns:
    model = RandomForestRegressor(random_state=42)
    grid_search = GridSearchCV(estimator=model, param_grid=param_grid, scoring='neg_mean_absolute_error', cv=5)
    grid_search.fit(X_train, y_train[nutrient])
    best_models[nutrient] = grid_search.best_estimator_
    print(f"Best parameters for {nutrient}: {grid_search.best_params_}")

# %% [markdown]
# #### GridSearch #4

# %%
param_grid = {
    'n_estimators': [100, 250, 275, 300],
    'max_depth': [9,10,11],
    'min_samples_split': [2, 3],
    'min_samples_leaf': [1]
}

# Dictionary to store best models
best_models = {}

# Train separate Random Forest models for each nutrient with GridSearchCV
for nutrient in y_train.columns:
    model = RandomForestRegressor(random_state=42)
    grid_search = GridSearchCV(estimator=model, param_grid=param_grid, scoring='neg_mean_absolute_error', cv=5)
    grid_search.fit(X_train, y_train[nutrient])
    best_models[nutrient] = grid_search.best_estimator_
    print(f"Best parameters for {nutrient}: {grid_search.best_params_}")

# %%
# Best hyperparameters for each nutrient
best_params = {
    'Mean_Nitrogen': {'max_depth': 9, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 275},
    'Mean_Phosphorous': {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 100},
    'Mean_Potassium': {'max_depth': 9, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 300}
}

# Instantiate separate SVR models for each nutrient with best parameters
models = {}
for nutrient in y_train.columns:
    model = RandomForestRegressor(**best_params[nutrient], random_state=42)
    model.fit(X_train, y_train[nutrient])
    models[nutrient] = model

# Evaluate the models
y_pred = pd.DataFrame()
for nutrient, model in models.items():
    y_pred[nutrient] = model.predict(X_test)

# Evaluate the models
for nutrient, model in models.items():
    mae = mean_absolute_error(y_test[nutrient], y_pred[nutrient])
    r2 = r2_score(y_test[nutrient], y_pred[nutrient])
    print(f'Mean Absolute Error for {nutrient}: {mae}')
    print(f'R-squared for {nutrient}: {r2}\n')
# Out:
# Mean Absolute Error for Mean_Nitrogen: 6.058812862420884
# R-squared for Mean_Nitrogen: 0.7544801398934843
#
# Mean Absolute Error for Mean_Phosphorous: 6.597481068871825
# R-squared for Mean_Phosphorous: 0.6465567675177559
#
# Mean Absolute Error for Mean_Potassium: 7.15919404152397
# R-squared for Mean_Potassium: 0.892776189047082

# %%
y_pred = pd.DataFrame()
for nutrient, model in models.items():
    y_pred[nutrient] = model.predict(X_test)

# Combine predictions (e.g., simple averaging)
ensemble_pred = y_pred.mean(axis=1)

# Evaluate the ensemble model
mae = mean_absolute_error(y_test.mean(axis=1), ensemble_pred)
r2 = r2_score(y_test.mean(axis=1), ensemble_pred)
print(f'Mean Absolute Error for the ensemble model: {mae}')
print(f'R-squared for the ensemble model: {r2}')
# Out:
# Mean Absolute Error for the ensemble model: 4.459934284814961
# R-squared for the ensemble model: 0.8771843007348313

# %% [markdown]
# ### XGBoost

# %%
models = {}
for nutrient in y_train.columns:
    model = XGBRegressor(random_state=42)
    model.fit(X_train, y_train[nutrient])
    models[nutrient] = model

# Testing models
y_pred = pd.DataFrame()
for nutrient, model in models.items():
    y_pred[nutrient] = model.predict(X_test)

# Evaluating models
for nutrient, model in models.items():
    mae = mean_absolute_error(y_test[nutrient], y_pred[nutrient])
    r2 = r2_score(y_test[nutrient], y_pred[nutrient])
    print(f'Mean Absolute Error for {nutrient}: {mae}')
    print(f'R-squared for {nutrient}: {r2}\n')

# %% [markdown]
# #### GridSearch #1

# %%
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [None, 5, 10],
    'eta': [0.3, 0.5, 0.7, 1],
    'subsample': [0.3, 0.5, 0.7, 1]
}

# Dictionary to store best models
best_models = {}

# Train separate Random Forest models for each nutrient with GridSearchCV
for nutrient in y_train.columns:
    model = XGBRegressor(random_state=42)
    grid_search = GridSearchCV(estimator=model, param_grid=param_grid, scoring='neg_mean_absolute_error', cv=5)
    grid_search.fit(X_train, y_train[nutrient])
    best_models[nutrient] = grid_search.best_estimator_
    print(f"Best parameters for {nutrient}: {grid_search.best_params_}")

# %%
# Best hyperparameters for each nutrient
best_params = {
    'Mean_Nitrogen': {'max_depth': 10, 'eta': 0.3, 'n_estimators': 100, 'subsample': 1},
    'Mean_Phosphorous': {'max_depth': 5, 'eta': 0.3, 'n_estimators': 100, 'subsample': 1},
    'Mean_Potassium': {'max_depth': 10, 'eta': 0.3, 'n_estimators': 100, 'subsample': 1}
}

# Instantiate separate XGBoost models for each nutrient with best parameters
models = {}
for nutrient in y_train.columns:
    model = XGBRegressor(**best_params[nutrient], random_state=42)
    model.fit(X_train, y_train[nutrient])
    models[nutrient] = model

# Evaluate the models
y_pred = pd.DataFrame()
for nutrient, model in models.items():
    y_pred[nutrient] = model.predict(X_test)

# Evaluate the models
for nutrient, model in models.items():
    mae = mean_absolute_error(y_test[nutrient], y_pred[nutrient])
    r2 = r2_score(y_test[nutrient], y_pred[nutrient])
    print(f'Mean Absolute Error for {nutrient}: {mae}')
    print(f'R-squared for {nutrient}: {r2}\n')

# %%
param_grid = {
    'n_estimators': [100, 200, 300],
    'max_depth': [5,7,10],
    'eta': [0.2,0.3,0.4],
    'subsample': [0.9, 1]
}

# Dictionary to store best models
best_models = {}

# Train separate Random Forest models for each nutrient with GridSearchCV
for nutrient in y_train.columns:
    model = XGBRegressor(random_state=42)
    grid_search = GridSearchCV(estimator=model, param_grid=param_grid, scoring='neg_mean_absolute_error', cv=5)
    grid_search.fit(X_train, y_train[nutrient])
    best_models[nutrient] = grid_search.best_estimator_
    print(f"Best parameters for {nutrient}: {grid_search.best_params_}")

# %%
# Best hyperparameters for each nutrient
best_params = {
    'Mean_Nitrogen': {'max_depth': 7, 'eta': 0.2, 'n_estimators': 100, 'subsample': 1},
    'Mean_Phosphorous': {'max_depth': 7, 'eta': 0.2, 'n_estimators': 100, 'subsample': 1},
    'Mean_Potassium': {'max_depth': 10, 'eta': 0.3, 'n_estimators': 100, 'subsample': 1}
}

# Instantiate separate XGBoost models for each nutrient with best parameters
models = {}
for nutrient in y_train.columns:
    model = XGBRegressor(**best_params[nutrient], random_state=42)
    model.fit(X_train, y_train[nutrient])
    models[nutrient] = model

# Evaluate the models
y_pred = pd.DataFrame()
for nutrient, model in models.items():
    y_pred[nutrient] = model.predict(X_test)

# Evaluate the models
for nutrient, model in models.items():
    mae = mean_absolute_error(y_test[nutrient], y_pred[nutrient])
    r2 = r2_score(y_test[nutrient], y_pred[nutrient])
    print(f'Mean Absolute Error for {nutrient}: {mae}')
    print(f'R-squared for {nutrient}: {r2}\n')

# %%
param_grid = {
    'n_estimators': [50,100,150],
    'max_depth': [6,8,10],
    'eta': [0.1, 0.2,0.3],
    'subsample': [1]
}

# Dictionary to store best models
best_models = {}

# Train separate Random Forest models for each nutrient with GridSearchCV
for nutrient in y_train.columns:
    model = XGBRegressor(random_state=42)
    grid_search = GridSearchCV(estimator=model, param_grid=param_grid, scoring='neg_mean_absolute_error', cv=5)
    grid_search.fit(X_train, y_train[nutrient])
    best_models[nutrient] = grid_search.best_estimator_
    print(f"Best parameters for {nutrient}: {grid_search.best_params_}")

# %%
# Best hyperparameters for each nutrient
best_params = {
    'Mean_Nitrogen': {'max_depth': 7, 'eta': 0.1, 'n_estimators': 100, 'subsample': 1},
    'Mean_Phosphorous': {'max_depth': 7, 'eta': 0.1, 'n_estimators': 100, 'subsample': 1},
    'Mean_Potassium': {'max_depth': 8, 'eta': 0.1, 'n_estimators': 100, 'subsample': 1}
}

# Instantiate separate XGBoost models for each nutrient with best parameters
models = {}
for nutrient in y_train.columns:
    model = XGBRegressor(**best_params[nutrient], random_state=42)
    model.fit(X_train, y_train[nutrient])
    models[nutrient] = model

# Evaluate the models
y_pred = pd.DataFrame()
for nutrient, model in models.items():
    y_pred[nutrient] = model.predict(X_test)

# Evaluate the models
for nutrient, model in models.items():
    mae = mean_absolute_error(y_test[nutrient], y_pred[nutrient])
    r2 = r2_score(y_test[nutrient], y_pred[nutrient])
    print(f'Mean Absolute Error for {nutrient}: {mae}')
    print(f'R-squared for {nutrient}: {r2}\n')

# %%
param_grid = {
    'n_estimators': [90, 100,110],
    'max_depth': [7,8,9],
    'eta': [0, 0.05, 0.1],
    'subsample': [1]
}

# Dictionary to store best models
best_models = {}

# Train separate Random Forest models for each nutrient with GridSearchCV
for nutrient in y_train.columns:
    model = XGBRegressor(random_state=42)
    grid_search = GridSearchCV(estimator=model, param_grid=param_grid, scoring='neg_mean_absolute_error', cv=5)
    grid_search.fit(X_train, y_train[nutrient])
    best_models[nutrient] = grid_search.best_estimator_
    print(f"Best parameters for {nutrient}: {grid_search.best_params_}")

# %%
# Best hyperparameters for each nutrient
best_params = {
    'Mean_Nitrogen': {'max_depth': 7, 'eta': 0.1, 'n_estimators': 110, 'subsample': 1},
    'Mean_Phosphorous': {'max_depth': 7, 'eta': 0.1, 'n_estimators': 90, 'subsample': 1},
    'Mean_Potassium': {'max_depth': 8, 'eta': 0.1, 'n_estimators': 90, 'subsample': 1}
}

# Instantiate separate XGBoost models for each nutrient with best parameters
models = {}
for nutrient in y_train.columns:
    model = XGBRegressor(**best_params[nutrient], random_state=42)
    model.fit(X_train, y_train[nutrient])
    models[nutrient] = model

# Evaluate the models
y_pred = pd.DataFrame()
for nutrient, model in models.items():
    y_pred[nutrient] = model.predict(X_test)

# Evaluate the models
for nutrient, model in models.items():
    mae = mean_absolute_error(y_test[nutrient], y_pred[nutrient])
    r2 = r2_score(y_test[nutrient], y_pred[nutrient])
    print(f'Mean Absolute Error for {nutrient}: {mae}')
    print(f'R-squared for {nutrient}: {r2}\n')
# Out:
# Mean Absolute Error for Mean_Nitrogen: 6.237210398676803
# R-squared for Mean_Nitrogen: 0.7473268457626852
#
# Mean Absolute Error for Mean_Phosphorous: 6.768298575022758
# R-squared for Mean_Phosphorous: 0.6416404587897769
#
# Mean Absolute Error for Mean_Potassium: 7.3058839196547085
# R-squared for Mean_Potassium: 0.8889748129381015

# %%
y_pred = pd.DataFrame()
for nutrient, model in models.items():
    y_pred[nutrient] = model.predict(X_test)

# Combine predictions (e.g., simple averaging)
ensemble_pred = y_pred.mean(axis=1)

# Evaluate the ensemble model
mae = mean_absolute_error(y_test.mean(axis=1), ensemble_pred)
r2 = r2_score(y_test.mean(axis=1), ensemble_pred)
print(f'Mean Absolute Error for the ensemble model: {mae}')
print(f'R-squared for the ensemble model: {r2}')
# Out:
# Mean Absolute Error for the ensemble model: 4.583384209656694
# R-squared for the ensemble model: 0.8732575055003186

# %% [markdown]
# ### Isolation forest

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.ensemble import IsolationForest
# Scale the NPK deviation features
scaler = MinMaxScaler()
desired_ratio = {'Nitrogen': 2, 'Phosphorus': 1, 'Potassium': 1}
# Scale NPK deviation features separately
scaled_mean_nitrogen = scaler.fit_transform(df['Mean_Nitrogen'].values.reshape(-1, 1)).flatten()
scaled_mean_phosphorus = scaler.fit_transform(df['Mean_Phosphorous'].values.reshape(-1, 1)).flatten()
scaled_mean_potassium = scaler.fit_transform(df['Mean_Potassium'].values.reshape(-1, 1)).flatten()

# Calculate NPK deviation using scaled mean values
nitrogen_deviation = abs(scaled_mean_nitrogen - desired_ratio['Nitrogen'])
phosphorus_deviation = abs(scaled_mean_phosphorus - desired_ratio['Phosphorus'])
potassium_deviation = abs(scaled_mean_potassium - desired_ratio['Potassium'])

# Combine scaled mean and deviation with environmental features
combined_df = pd.DataFrame({
    'Temp01': df['Temp01'],
    'Hum01': df['Hum01'],
    'Moisture': df['Mean_Moisture'],
    'NPK_Nitrogen_Deviation': nitrogen_deviation,
    'NPK_Phosphorus_Deviation': phosphorus_deviation,
    'NPK_Potassium_Deviation': potassium_deviation
})

# Initialize and train the Isolation Forest model with combined data
isolation_forest = IsolationForest(contamination=0.05, random_state=49)

isolation_forest.fit(combined_df)


# Predict outliers/anomalies (1 for inliers, -1 for outliers)
predictions = isolation_forest.predict(combined_df)

# Identify outliers/anomalies in the original DataFrame
outliers = df[predictions == -1]
inliers = df[predictions == 1]
anomaly_scores = isolation_forest.decision_function(combined_df)

# %%
outliers.info()

# %%
outliers.describe() #78 outliers

# %%
inliers = df[predictions == 1]
inliers.describe()

# %%
import shap

# Train your anomaly detection model (e.g., Isolation Forest) and generate anomaly scores

# Identify top outliers based on anomaly scores
sorted_indices = np.argsort(anomaly_scores)
sorted_indices = sorted_indices[::-1]
top_outlier_indices = sorted_indices[:1]
top_outliers = combined_df.iloc[top_outlier_indices]

# Calculate SHAP values for the selected outlier data points
explainer = shap.Explainer(isolation_forest)  # Replace 'model' with your anomaly detection model
shap_values = explainer.shap_values(top_outliers)  # Replace 'outlier_data' with your selected outlier data points

# Visualize SHAP explanations for individual outlier predictions
shap.summary_plot(shap_values, features=top_outliers)
